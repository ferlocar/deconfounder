# %% [markdown]
# # Load and create data sets

# %% [markdown]
# Load data.

# %%
### LINES TO IMPORT THE DECONFOUNDER PACKAGE IN THE PARENT FOLDER ###
import os
import sys
sys.path.append("..")
### IMPORTS
from deconfounder.causal_tree import CausalTree
from deconfounder.causal_forest import CausalForest
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import numpy as np
from numpy.polynomial.polynomial import polyfit
import pandas as pd
import scipy.stats as st
from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict
import time
from sklearn.utils.parallel import Parallel, delayed

# %%
# Load data
df = pd.read_csv("../data/criteo-uplift-v2.1.csv")
df = df.sample(frac=1, random_state=42)
all_features = df.columns.values[:12].tolist()

# %% [markdown]
# Find the feature that is correalted the most with the outcome and remove that feature (i.e., the confounder).

# %%
corr_matrix = df[all_features + ['visit']].corr()
confounder = corr_matrix['visit'][:-1].sort_values().index.values[-1]
print(confounder)
limited_features = list(all_features)
limited_features.remove(confounder)
# Out:
# f9

# %% [markdown]
# Obtain observational data. Drop observations using the confounder.

# %%
adverse = True
resdir = "advconf_results" if adverse else "results"

# %%
def print_outcomes(data):
    means = data.groupby('treatment').visit.mean()
    print(f"Size of data set: {data.shape[0]:,}")
    print(f"Avg. Outcome (treated): {np.round(means.loc[1]*100, 2)}%")
    print(f"Avg. Outcome (control): {np.round(means.loc[0]*100, 2)}%")
    print(f"Estimated avg. effect: {np.round((means.loc[1]-means.loc[0])*100, 2)}%")

train_frac = 0.5
train_size = int(df.shape[0]*train_frac)
obs_df = df[:train_size]
train_df = df[:train_size]
drop_frac = 0.1

conf_ranking = obs_df[confounder].rank(method="first")
if not adverse:
    keep =  ((obs_df.treatment == 1) & (conf_ranking > int(train_size * drop_frac))) | \
            ((obs_df.treatment == 0) & (conf_ranking < int(train_size * (1 - drop_frac))))
else:
    keep =  ((obs_df.treatment == 0) & (conf_ranking > int(train_size * drop_frac))) | \
        ((obs_df.treatment == 1) & (conf_ranking < int(train_size * (1 - drop_frac))))
        
obs_df = train_df[keep]
print("Observational (naive) setup")
print_outcomes(obs_df)
print("-------------")
exp_df = train_df.sample(n=obs_df.shape[0],random_state=42)
print("Experimental setup")
print_outcomes(exp_df)
print("-------------")
print("Entire data")
print_outcomes(df)
# Out:
# Observational (naive) setup
# Size of data set: 6,284,105
# Avg. Outcome (treated): 1.65%
# Avg. Outcome (control): 4.17%
# Estimated avg. effect: -2.53%
# -------------
# Experimental setup
# Size of data set: 6,284,105
# Avg. Outcome (treated): 4.86%
# Avg. Outcome (control): 3.8%
# Estimated avg. effect: 1.06%
# -------------
# Entire data
# Size of data set: 13,979,592
# Avg. Outcome (treated): 4.85%
# Avg. Outcome (control): 3.82%
# Estimated avg. effect: 1.03%

# %% [markdown]
# Build causal tree using observational data. Control for observable confounding.

# %%
def fit_tree(df_causal, tree_type=CausalForest, min_samples_leaf=5000, tune=False, params=None, scoring=None, verbose=True):    
    X = df_causal[limited_features + ['treatment']].rename(columns={"treatment":"treated"})
    y =  df_causal.visit
    # Fit and tune causal tree
    start_time = time.time()
    if tune:
        if params is None:
            params = range(1000, 10000, 1000)
        tuned_parameters = [{'min_samples_leaf': params}]
        grid_tree = GridSearchCV(tree_type(random_state=42, n_estimators=10), tuned_parameters, cv=4, 
                                 verbose=10, n_jobs=4, scoring=scoring)
        grid_tree.fit(X, y)
        print("Best parameters set found on development set:")
        print(grid_tree.best_params_)
        tree_model = grid_tree.best_estimator_
    else:
        ### WARNING: if n_jobs is different from 1, the code breaks
        tree_model = tree_type(min_samples_leaf=min_samples_leaf, random_state=42, n_estimators=10)
        tree_model.fit(X, y)
    if verbose:
        print("--- Time to fit (and tune) causal tree %s seconds ---" % (time.time() - start_time))
    return tree_model

#obs_tree = fit_tree(obs_df, tune=True, params=[8000, 16000, 32000, 64000, 128000])
#Best parameters set found on development set:
#{'min_samples_leaf': 32000}
#--- Time to fit (and tune) causal tree 1082.7572462558746 seconds ---
obs_tree = fit_tree(obs_df, min_samples_leaf=32000)
# Out:
# --- Time to fit (and tune) causal tree 278.5450804233551 seconds ---

# %% [markdown]
# Obtain evaluation data

# %%
eval_df = df[train_size:].copy()

# %% [markdown]
# Estimated average causal effect after accounting for observed confounding.

# %%
print("Observational ('smart') setup")
obs_preds = obs_tree.predict(eval_df[limited_features])
obs_avg_effect = obs_preds.mean()
print(f"Estimated avg. effect: {np.round(obs_avg_effect*100, 2)}%")
# Out:
# Observational ('smart') setup
# Estimated avg. effect: -1.3%

# %% [markdown]
# # Approach 1: Domain Knowledge

# %% [markdown]
# Suppose visit value is \\$ 0.50 and the cost is \\$ 0.01. How does the bias may affect ability to identify profitable customers?

# %%
visit_value = 0.49
ad_cost = 0.01
total_impressions = 1000000
boundary = ad_cost/(visit_value+ad_cost)

def get_avg_benefit(e_df, boundary=None):
    if boundary is None:
        boundary = ad_cost/(visit_value+ad_cost)
    targeted = e_df.pred > boundary 
    avg_outcomes = e_df[targeted].groupby('treatment').visit.mean()
    fraction = targeted.mean()
    additional_visits = (avg_outcomes.loc[1] - avg_outcomes.loc[0]) * fraction 
    benefit = (additional_visits*visit_value - fraction*ad_cost)*total_impressions
    print(f"Benefit ($) per 1 MM users: {round(benefit):,}")
    return benefit

print("Real benefit (compared with sensitivity analysis)")
print("------")
print("Observational")
eval_df['pred'] = obs_preds
obs_benefit = get_avg_benefit(eval_df)
# Out:
# Real benefit (compared with sensitivity analysis)
# ------
# Observational
# Benefit ($) per 1 MM users: 193

# %% [markdown]
# Get cross-validation predictions.

# %%
X = obs_df[limited_features + ['treatment']].rename(columns={"treatment":"treated"})
y =  obs_df.visit
cross_preds = cross_val_predict(CausalForest(min_samples_leaf=obs_tree.min_samples_leaf, random_state=42, n_estimators=10), 
                                X, y, cv=5, verbose=10, n_jobs=5)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:  3.1min remaining:  4.7min
# [Parallel(n_jobs=5)]: Done   3 out of   5 | elapsed:  3.2min remaining:  2.1min
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:  3.2min remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:  3.2min finished

# %%
targeted = cross_preds > boundary
biased_avg_effect = obs_preds.mean()
estimated_effects = obs_tree.predict(obs_df[limited_features])

bias_size = 0.87
real_size = (1-bias_size)
additional_visits = ((estimated_effects * real_size) * targeted).mean()
benefit =  round((additional_visits*visit_value - targeted.mean()*ad_cost)*total_impressions)
benefit
# Out:
# -301

# %% [markdown]
# Assess how much could the bias affect the decisions.

# %%
means = eval_df.groupby('treatment').visit.mean()
avg_effect = means.loc[1]-means.loc[0]

real_avg_bias = round(1 - avg_effect/biased_avg_effect, 2)

bias_sizes = np.arange(11)/10
benefits = []
for bias_size in bias_sizes:
    real_size = (1-bias_size)
    additional_visits = ((estimated_effects * real_size) * targeted).mean()
    benefit =  round((additional_visits*visit_value - targeted.mean()*ad_cost)*total_impressions)
    benefits.append(benefit)

figs = plt.plot(bias_sizes*100, benefits, label="Estimation (w. sensitivity analysis)")
plt.xlabel("Bias size (as % of estimated effect)")
plt.ylabel("Profit (per 1MM consumers)")
# Set Y axis
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
figs[0].axes.yaxis.set_major_formatter(tick)
# Set X axis
figs[0].axes.xaxis.set_major_formatter(mtick.PercentFormatter())
# Break-even line
plt.plot([0, 100], [0, 0], linestyle='--', color='black')
plt.plot([real_avg_bias*100], [obs_benefit], marker="*", label="Ground truth")
plt.legend()
# plt.savefig("sensitivity_analysis.png", dpi=200, bbox_inches="tight")

# %% [markdown]
# # Approach 2: What if there is some experimental data?

# %% [markdown]
# What's the best tree we could get with limited experimental data?

# %%
limited_exp = exp_df.sample(50000,random_state=42)
limited_tree = fit_tree(limited_exp, tune=True, params=np.arange(1, 11)*1000)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# [CV 2/4; 1/10] START min_samples_leaf=1000......................................
# [CV 1/4; 1/10] START min_samples_leaf=1000......................................
# [CV 4/4; 1/10] START min_samples_leaf=1000......................................
# [CV 3/4; 1/10] START min_samples_leaf=1000......................................
# [CV 2/4; 1/10] END .......min_samples_leaf=1000;, score=0.001 total time=   0.5s
# [CV 1/4; 2/10] START min_samples_leaf=2000......................................
# [CV 1/4; 1/10] END .......min_samples_leaf=1000;, score=0.000 total time=   0.5s
# [CV 2/4; 2/10] START min_samples_leaf=2000......................................
# [CV 3/4; 1/10] END ......min_samples_leaf=1000;, score=-0.000 total time=   0.5s
# [CV 4/4; 1/10] END .......min_samples_leaf=1000;, score=0.000 total time=   0.5s
# [CV 3/4; 2/10] START min_samples_leaf=2000......................................
# [CV 4/4; 2/10] START min_samples_leaf=2000......................................
# [CV 1/4; 2/10] END .......min_samples_leaf=2000;, score=0.000 total time=   0.4s
# [CV 1/4; 3/10] START min_samples_leaf=3000......................................
# [CV 2/4; 2/10] END .......min_samples_leaf=2000;, score=0.000 total time=   0.4s
# [CV 2/4; 3/10] START min_samples_leaf=3000......................................
# [CV 3/4; 2/10] END ......min_samples_leaf=2000;, score=-0.000 total time=   0.4s
# [CV 3/4; 3/10] START min_samples_leaf=3000......................................
# [CV 4/4; 2/10] END .......min_samples_leaf=2000;, score=0.000 total time=   0.4s
# [CV 4/4; 3/10] START min_samples_leaf=3000......................................
# [CV 1/4; 3/10] END .......min_samples_leaf=3000;, score=0.000 total time=   0.3s
# [CV 1/4; 4/10] START min_samples_leaf=4000......................................
# [CV 2/4; 3/10] END .......min_samples_leaf=3000;, score=0.000 total time=   0.3s
# [CV 2/4; 4/10] START min_samples_leaf=4000......................................
# [CV 3/4; 3/10] END ......min_samples_leaf=3000;, score=-0.000 total time=   0.3s
# [CV 3/4; 4/10] START min_samples_leaf=4000......................................
# [CV 4/4; 3/10] END .......min_samples_leaf=3000;, score=0.000 total time=   0.3s
# [CV 4/4; 4/10] START min_samples_leaf=4000......................................
# [CV 1/4; 4/10] END .......min_samples_leaf=4000;, score=0.000 total time=   0.3s
# [CV 1/4; 5/10] START min_samples_leaf=5000......................................
# [CV 2/4; 4/10] END .......min_samples_leaf=4000;, score=0.000 total time=   0.2s
# [CV 2/4; 5/10] START min_samples_leaf=5000......................................
# [CV 3/4; 4/10] END ......min_samples_leaf=4000;, score=-0.000 total time=   0.3s
# [CV 3/4; 5/10] START min_samples_leaf=5000......................................
# [CV 4/4; 4/10] END .......min_samples_leaf=4000;, score=0.000 total time=   0.3s
# [CV 4/4; 5/10] START min_samples_leaf=5000......................................
# [CV 1/4; 5/10] END .......min_samples_leaf=5000;, score=0.000 total time=   0.2s
# [CV 1/4; 6/10] START min_samples_leaf=6000......................................
# [CV 2/4; 5/10] END .......min_samples_leaf=5000;, score=0.000 total time=   0.2s
# [CV 2/4; 6/10] START min_samples_leaf=6000......................................
# [CV 3/4; 5/10] END .......min_samples_leaf=5000;, score=0.000 total time=   0.2s
# [CV 3/4; 6/10] START min_samples_leaf=6000......................................
# [CV 4/4; 5/10] END .......min_samples_leaf=5000;, score=0.000 total time=   0.2s
# [CV 4/4; 6/10] START min_samples_leaf=6000......................................
# [CV 1/4; 6/10] END .......min_samples_leaf=6000;, score=0.000 total time=   0.2s
# [CV 1/4; 7/10] START min_samples_leaf=7000......................................
# [CV 2/4; 6/10] END .......min_samples_leaf=6000;, score=0.000 total time=   0.2s
# [CV 2/4; 7/10] START min_samples_leaf=7000......................................
# [CV 3/4; 6/10] END .......min_samples_leaf=6000;, score=0.000 total time=   0.2s
# [CV 3/4; 7/10] START min_samples_leaf=7000......................................
# [CV 4/4; 6/10] END .......min_samples_leaf=6000;, score=0.000 total time=   0.2s
# [CV 4/4; 7/10] START min_samples_leaf=7000......................................
# [CV 1/4; 7/10] END .......min_samples_leaf=7000;, score=0.000 total time=   0.2s
# [CV 1/4; 8/10] START min_samples_leaf=8000......................................
# [CV 2/4; 7/10] END .......min_samples_leaf=7000;, score=0.000 total time=   0.2s
# [CV 2/4; 8/10] START min_samples_leaf=8000......................................
# [CV 3/4; 7/10] END .......min_samples_leaf=7000;, score=0.000 total time=   0.2s
# [CV 3/4; 8/10] START min_samples_leaf=8000......................................
# [CV 4/4; 7/10] END .......min_samples_leaf=7000;, score=0.000 total time=   0.2s
# [CV 4/4; 8/10] START min_samples_leaf=8000......................................
# [CV 1/4; 8/10] END .......min_samples_leaf=8000;, score=0.000 total time=   0.2s
# [CV 1/4; 9/10] START min_samples_leaf=9000......................................
# [CV 2/4; 8/10] END .......min_samples_leaf=8000;, score=0.000 total time=   0.2s
# [CV 2/4; 9/10] START min_samples_leaf=9000......................................
# [CV 3/4; 8/10] END .......min_samples_leaf=8000;, score=0.000 total time=   0.2s
# [CV 3/4; 9/10] START min_samples_leaf=9000......................................
# [CV 4/4; 8/10] END .......min_samples_leaf=8000;, score=0.000 total time=   0.2s
# [CV 4/4; 9/10] START min_samples_leaf=9000......................................
# [CV 1/4; 9/10] END .......min_samples_leaf=9000;, score=0.000 total time=   0.2s
# [CV 1/4; 10/10] START min_samples_leaf=10000....................................
# [CV 2/4; 9/10] END .......min_samples_leaf=9000;, score=0.000 total time=   0.2s
# [CV 2/4; 10/10] START min_samples_leaf=10000....................................
# [CV 3/4; 9/10] END .......min_samples_leaf=9000;, score=0.000 total time=   0.2s
# [CV 3/4; 10/10] START min_samples_leaf=10000....................................
# [CV 4/4; 9/10] END .......min_samples_leaf=9000;, score=0.000 total time=   0.2s
# [CV 4/4; 10/10] START min_samples_leaf=10000....................................
# [CV 1/4; 10/10] END .....min_samples_leaf=10000;, score=0.000 total time=   0.2s
# [CV 2/4; 10/10] END .....min_samples_leaf=10000;, score=0.000 total time=   0.2s
# [CV 3/4; 10/10] END .....min_samples_leaf=10000;, score=0.000 total time=   0.2s
# [CV 4/4; 10/10] END .....min_samples_leaf=10000;, score=0.000 total time=   0.2s
# Best parameters set found on development set:
# {'min_samples_leaf': 1000}
# --- Time to fit (and tune) causal tree 5.039460897445679 seconds ---

# %% [markdown]
# Compare each other. Experimental does better.

# %%
means = eval_df.groupby('treatment').visit.mean()
avg_effect = means.loc[1]-means.loc[0]
total_impressions = 1000000
size = 100

def plot_random(e_df):
    means = e_df.groupby('treatment').visit.mean()
    avg_effect = means.loc[1]-means.loc[0]
    fractions = (np.arange(size)+1)/size
    plt.plot(fractions*100, fractions*avg_effect*total_impressions, 
             color='black', linestyle='dashed', label="Random targeting")
    plt.legend()

def evaluate(e_df, title):
    e_df = e_df.sort_values('pred', ascending=False)
    cum_per = np.arange(e_df.shape[0]) / e_df.shape[0]
    fractions = []
    effects = []
    for i in range(size):
        targeted = cum_per < (i+1)/size
        fraction = targeted.mean()
        avg_outcomes = e_df[targeted].groupby('treatment').visit.mean()
        additional_visits = (avg_outcomes.loc[1] - avg_outcomes.loc[0]) * fraction * total_impressions
        fractions.append(fraction)
        effects.append(additional_visits)
    figs = plt.plot(np.array(fractions)*100, effects, label=title)
    plt.xlabel("% of users targeted")
    plt.ylabel("Incremental visits (per 1MM consumers)")
    # Set Y axis
    fmt = '{x:,.0f}'
    tick = mtick.StrMethodFormatter(fmt)
    figs[0].axes.yaxis.set_major_formatter(tick)
    # Set X axis
    figs[0].axes.xaxis.set_major_formatter(mtick.PercentFormatter())
    plt.legend()

# %%
X = limited_exp[limited_features + ['treatment']].rename(columns={"treatment":"treated"})
y =  limited_exp.visit
exp_cross_preds = cross_val_predict(CausalForest(min_samples_leaf=limited_tree.min_samples_leaf, random_state=42, 
                                                 n_estimators=10), X, y, cv=10, verbose=10)

copy_exp_df = limited_exp.copy()
size=30
copy_exp_df['pred'] = obs_tree.predict(copy_exp_df[limited_features])
evaluate(copy_exp_df, "Observational model")
copy_exp_df['pred'] = exp_cross_preds
evaluate(copy_exp_df, "Experimental model")
#plt.axhline(y=0, color='black', linestyle='--')
plot_random(copy_exp_df)
plt.xlim(left=0)
plt.savefig(f"../{resdir}/eval_comparison.png", dpi=200, bbox_inches="tight")
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    4.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    5.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    6.0s finished

# %% [markdown]
# Average effect estimated by the experimental tree.

# %%
exp_cross_preds.mean() * 100
# Out:
# 0.8664567802702633

# %% [markdown]
# Benefit evaluation

# %%
print("Observational")
copy_exp_df['pred'] = obs_tree.predict(copy_exp_df[limited_features])
obs_benefit = get_avg_benefit(copy_exp_df)
print("Experimental")
copy_exp_df['pred'] = exp_cross_preds
exp_benefit = get_avg_benefit(copy_exp_df)
# Out:
# Observational
# Benefit ($) per 1 MM users: 825
# Experimental
# Benefit ($) per 1 MM users: 2,507

# %%
print("Observational")
eval_df['pred'] = obs_preds
obs_benefit = get_avg_benefit(eval_df)
print("Experimental")
eval_df['pred'] = limited_tree.predict(eval_df[limited_features])
exp_benefit = get_avg_benefit(eval_df)
# Out:
# Observational
# Benefit ($) per 1 MM users: 193
# Experimental
# Benefit ($) per 1 MM users: 1,818

# %% [markdown]
# # Approach 3: What if we can invest in data?

# %%
def get_improvement(e_df, top=0.3):
    #targeted = e_df.pred >= np.percentile(e_df.pred, 100-top)
    targeted = eval_df.pred.argsort().tail(int(eval_df.shape[0] * top))
    avg_outcomes = e_df.iloc[targeted].groupby('treatment').visit.mean()
    additional_visits = (avg_outcomes.loc[1] - avg_outcomes.loc[0]) * top * total_impressions
    print(f"Additional visits: {additional_visits}")
    return additional_visits

# %%
start_time = time.time()
eval_df['pred'] = obs_tree.predict(eval_df[limited_features])
obs_benefit = get_improvement(eval_df)

def run_single_experimental_model(exp_size, seed):

    # print(f"Experimental data size: {exp_size}")
    subset_exp = exp_df.sample(exp_size,random_state=seed)
    subset_tree = fit_tree(subset_exp, tune=False, min_samples_leaf=limited_tree.min_samples_leaf)
    eval_df['pred'] = subset_tree.predict(eval_df[limited_features])
    exp_benefit = get_improvement(eval_df)
    improvement = 100 * (exp_benefit/obs_benefit - 1)
    # print(f"Improvement: {improvement}")
    result = {'seed': seed, 'size': exp_size, 'improvement': improvement}
    return result

curve_sizes = np.array([6000, 12000, 25000, 50000, 100000, 200000, 400000])
labels = ['6k', '12k', '25k', '50k', '100k', '200k', '400k']
size2label = dict((curve_sizes[i], labels[i]) for i in range(len(labels)))

parallel = Parallel(n_jobs=16)
func = delayed(run_single_experimental_model)

curve_results = parallel(func(
    exp_size=exp_size,
    seed=seed
    )
    for seed in range(0, 100)
        for exp_size in curve_sizes
)

curve_results = pd.DataFrame(curve_results)
curve_results.to_csv(f'../{resdir}/learning_curve_results.csv', index=False)

print('Done!')
print(f'Total time: {(time.time()-start_time)/60:.3f} minutes')
# Out:
# Additional visits: 2825.4716753117664
# --- Time to fit (and tune) causal tree 0.03486943244934082 seconds ---
# --- Time to fit (and tune) causal tree 0.03512716293334961 seconds ---
# --- Time to fit (and tune) causal tree 0.035050392150878906 seconds ---
# --- Time to fit (and tune) causal tree 0.08199930191040039 seconds ---
# --- Time to fit (and tune) causal tree 0.08354043960571289 seconds ---
# --- Time to fit (and tune) causal tree 0.08371305465698242 seconds ---
# --- Time to fit (and tune) causal tree 0.23867273330688477 seconds ---
# --- Time to fit (and tune) causal tree 0.22934937477111816 seconds ---
# --- Time to fit (and tune) causal tree 0.8092496395111084 seconds ---
# --- Time to fit (and tune) causal tree 0.813812255859375 seconds ---
# --- Time to fit (and tune) causal tree 2.30057430267334 seconds ---
# --- Time to fit (and tune) causal tree 2.6332662105560303 seconds ---
# Additional visits: 8150.914822483955
# Additional visits: 8867.840786078317
# Additional visits: 8563.172829821384
# Additional visits: 8644.019520249632
# --- Time to fit (and tune) causal tree 0.24124884605407715 seconds ---
# Additional visits: 8535.630282815802
# Additional visits: 8921.048145157632
# --- Time to fit (and tune) causal tree 0.7599804401397705 seconds ---
# --- Time to fit (and tune) causal tree 0.03839707374572754 seconds ---
# Additional visits: 8695.474241542648
# Additional visits: 8681.406752797506
# --- Time to fit (and tune) causal tree 0.08663082122802734 seconds ---
# --- Time to fit (and tune) causal tree 0.2611703872680664 seconds ---
# --- Time to fit (and tune) causal tree 2.51501202583313 seconds ---
# Additional visits: 8854.482771186043
# Additional visits: 8573.581974240178
# --- Time to fit (and tune) causal tree 7.715270042419434 seconds ---
# --- Time to fit (and tune) causal tree 0.8375322818756104 seconds ---
# --- Time to fit (and tune) causal tree 8.286500692367554 seconds ---
# Additional visits: 8556.791177018435
# Additional visits: 8208.34688327937
# Additional visits: 8050.5875336787085
# Additional visits: 8758.111224334392
# --- Time to fit (and tune) causal tree 2.5138964653015137 seconds ---
# --- Time to fit (and tune) causal tree 0.03730320930480957 seconds ---
# Additional visits: 9094.593309406453
# --- Time to fit (and tune) causal tree 0.08390522003173828 seconds ---
# Additional visits: 8433.610794980284
# --- Time to fit (and tune) causal tree 0.22405648231506348 seconds ---
# Additional visits: 7827.06519652194
# --- Time to fit (and tune) causal tree 7.381276607513428 seconds ---
# --- Time to fit (and tune) causal tree 0.7828798294067383 seconds ---
# Additional visits: 2053.2577558035678
# Additional visits: 8463.207198714243
# --- Time to fit (and tune) causal tree 2.3527462482452393 seconds ---
# Additional visits: 8640.122761838684
# Additional visits: 1054.383321546463
# --- Time to fit (and tune) causal tree 0.037786006927490234 seconds ---
# --- Time to fit (and tune) causal tree 0.08138585090637207 seconds ---
# Additional visits: 8249.515618028656
# Additional visits: 8615.576447256186
# --- Time to fit (and tune) causal tree 7.648959636688232 seconds ---
# Additional visits: 8636.903364779157
# --- Time to fit (and tune) causal tree 0.23680353164672852 seconds ---
# Additional visits: 8618.346851965827
# --- Time to fit (and tune) causal tree 0.7158627510070801 seconds ---
# Additional visits: 8323.544860914992
# Additional visits: 2562.866161638115
# --- Time to fit (and tune) causal tree 0.038949012756347656 seconds ---
# --- Time to fit (and tune) causal tree 2.423243999481201 seconds ---
# Additional visits: 8708.660656715694
# Additional visits: 8431.75985811653
# --- Time to fit (and tune) causal tree 0.08183836936950684 seconds ---
# --- Time to fit (and tune) causal tree 0.2459273338317871 seconds ---
# Additional visits: 8417.861710364707
# Additional visits: 8460.323181009577
# --- Time to fit (and tune) causal tree 22.231626510620117 seconds ---
# --- Time to fit (and tune) causal tree 8.15916633605957 seconds ---
# --- Time to fit (and tune) causal tree 0.6976604461669922 seconds ---
# --- Time to fit (and tune) causal tree 22.82981038093567 seconds ---
# Additional visits: 4071.4100773249884
# Additional visits: 8992.382533820088
# Additional visits: 8636.544943382938
# --- Time to fit (and tune) causal tree 2.3915860652923584 seconds ---
# Additional visits: 4200.609624348419
# --- Time to fit (and tune) causal tree 7.412804365158081 seconds ---
# --- Time to fit (and tune) causal tree 0.038884878158569336 seconds ---
# --- Time to fit (and tune) causal tree 0.08713793754577637 seconds ---
# --- Time to fit (and tune) causal tree 20.90095829963684 seconds ---
# Additional visits: 8237.347833017386
# Additional visits: 8575.918125588307
# --- Time to fit (and tune) causal tree 0.24616765975952148 seconds ---
# --- Time to fit (and tune) causal tree 0.745377779006958 seconds ---
# Additional visits: 8647.130877520889
# Additional visits: 5257.324800975012
# --- Time to fit (and tune) causal tree 19.47808527946472 seconds ---
# Additional visits: 8699.62258779317
# Additional visits: 8600.510873374073
# --- Time to fit (and tune) causal tree 7.566421270370483 seconds ---
# --- Time to fit (and tune) causal tree 0.0372462272644043 seconds ---
# --- Time to fit (and tune) causal tree 2.6917881965637207 seconds ---
# Additional visits: 8662.07595355776
# Additional visits: 8972.084813794578
# Additional visits: 8352.07216523063
# --- Time to fit (and tune) causal tree 0.08488750457763672 seconds ---
# Additional visits: 8762.966260874528
# --- Time to fit (and tune) causal tree 0.24093246459960938 seconds ---
# Additional visits: 8616.90352329389
# --- Time to fit (and tune) causal tree 0.7789595127105713 seconds ---
# Additional visits: 8452.143527201468
# Additional visits: 4848.3021506620635
# --- Time to fit (and tune) causal tree 20.301908016204834 seconds ---
# --- Time to fit (and tune) causal tree 0.03753352165222168 seconds ---
# Additional visits: 8642.502713775773
# --- Time to fit (and tune) causal tree 0.08343744277954102 seconds ---
# --- Time to fit (and tune) causal tree 2.7104389667510986 seconds ---
# Additional visits: 6862.180749193449
# --- Time to fit (and tune) causal tree 8.100114107131958 seconds ---
# --- Time to fit (and tune) causal tree 0.2577342987060547 seconds ---
# Additional visits: 8490.39288974626
# --- Time to fit (and tune) causal tree 19.548575162887573 seconds ---
# Additional visits: 8979.570704856396
# Additional visits: 3630.039645321667
# Additional visits: 8327.277038179784
# Additional visits: 9071.384408917525
# --- Time to fit (and tune) causal tree 0.7797927856445312 seconds ---
# Additional visits: 8382.446702919622
# --- Time to fit (and tune) causal tree 0.03793525695800781 seconds ---
# --- Time to fit (and tune) causal tree 0.08047127723693848 seconds ---
# Additional visits: 8518.59464572998
# --- Time to fit (and tune) causal tree 0.22134923934936523 seconds ---
# --- Time to fit (and tune) causal tree 2.537872791290283 seconds ---
# --- Time to fit (and tune) causal tree 8.240855932235718 seconds ---
# Additional visits: 7988.739827599834
# Additional visits: 2041.0333503924649
# Additional visits: 8539.622187208593
# Additional visits: 8661.869193856508
# --- Time to fit (and tune) causal tree 0.6991086006164551 seconds ---
# Additional visits: 6578.247142696149
# --- Time to fit (and tune) causal tree 0.037987470626831055 seconds ---
# Additional visits: 8567.458726631312
# --- Time to fit (and tune) causal tree 21.679112672805786 seconds ---
# --- Time to fit (and tune) causal tree 0.08534383773803711 seconds ---
# Additional visits: 8505.969245975584
# Additional visits: 8979.553793217812
# --- Time to fit (and tune) causal tree 2.3245582580566406 seconds ---
# --- Time to fit (and tune) causal tree 6.975290775299072 seconds ---
# --- Time to fit (and tune) causal tree 0.2622840404510498 seconds ---
# --- Time to fit (and tune) causal tree 0.8130230903625488 seconds ---
# Additional visits: 8872.785617439651
# Additional visits: 5890.280734036814
# Additional visits: 8814.668531707564
# Additional visits: 8766.500342973606
# Additional visits: 3801.016110987673
# --- Time to fit (and tune) causal tree 0.03861069679260254 seconds ---
# --- Time to fit (and tune) causal tree 2.472926378250122 seconds ---
# Additional visits: 8463.70009979173
# --- Time to fit (and tune) causal tree 6.859853267669678 seconds ---
# --- Time to fit (and tune) causal tree 0.09069347381591797 seconds ---
# --- Time to fit (and tune) causal tree 0.23944926261901855 seconds ---
# --- Time to fit (and tune) causal tree 21.14881134033203 seconds ---
# Additional visits: 7833.510895505443
# Additional visits: 8699.709970939803
# --- Time to fit (and tune) causal tree 0.7959244251251221 seconds ---
# Additional visits: 7704.842737903297
# Additional visits: 7242.720404574507
# Additional visits: 8772.782872889036
# --- Time to fit (and tune) causal tree 0.03814244270324707 seconds ---
# Additional visits: 8845.28534506247
# Additional visits: 8242.121918538263
# --- Time to fit (and tune) causal tree 0.08429622650146484 seconds ---
# --- Time to fit (and tune) causal tree 0.25032472610473633 seconds ---
# --- Time to fit (and tune) causal tree 2.7218332290649414 seconds ---
# --- Time to fit (and tune) causal tree 22.127105712890625 seconds ---
# Additional visits: 9078.247940331898
# --- Time to fit (and tune) causal tree 8.212798833847046 seconds ---
# --- Time to fit (and tune) causal tree 17.916231155395508 seconds ---
# Additional visits: 8492.970285651201
# --- Time to fit (and tune) causal tree 0.8651156425476074 seconds ---
# Additional visits: 3746.810840945726
# Additional visits: 8797.976039261752
# Additional visits: 8540.932974600257
# --- Time to fit (and tune) causal tree 0.03652763366699219 seconds ---
# Additional visits: 8365.333794030223
# --- Time to fit (and tune) causal tree 0.08299827575683594 seconds ---
# --- Time to fit (and tune) causal tree 2.4591639041900635 seconds ---
# Additional visits: 8783.341968595983
# Additional visits: 8698.277906685242
# --- Time to fit (and tune) causal tree 0.23579120635986328 seconds ---
# --- Time to fit (and tune) causal tree 8.15983533859253 seconds ---
# --- Time to fit (and tune) causal tree 0.7857232093811035 seconds ---
# Additional visits: 5567.824809057203
# Additional visits: 8054.027085988952
# Additional visits: 8382.502686256003
# --- Time to fit (and tune) causal tree 20.185376405715942 seconds ---
# Additional visits: 8495.831926016926
# --- Time to fit (and tune) causal tree 0.038549184799194336 seconds ---
# --- Time to fit (and tune) causal tree 6.385474920272827 seconds ---
# Additional visits: 8122.742428116519
# Additional visits: 8534.967424429055
# --- Time to fit (and tune) causal tree 0.0836491584777832 seconds ---
# Additional visits: 8783.715620093011
# --- Time to fit (and tune) causal tree 2.5676960945129395 seconds ---
# Additional visits: 8025.362674706245
# --- Time to fit (and tune) causal tree 0.25354790687561035 seconds ---
# Additional visits: 8513.542904388964
# --- Time to fit (and tune) causal tree 0.7818188667297363 seconds ---
# Additional visits: 8161.049918336822
# Additional visits: 8541.059677303023
# --- Time to fit (and tune) causal tree 0.03752279281616211 seconds ---
# --- Time to fit (and tune) causal tree 2.509849786758423 seconds ---
# Additional visits: 8556.89502685904
# Additional visits: 8937.388222660298
# --- Time to fit (and tune) causal tree 22.163897037506104 seconds ---
# --- Time to fit (and tune) causal tree 0.08385062217712402 seconds ---
# --- Time to fit (and tune) causal tree 0.24755215644836426 seconds ---
# --- Time to fit (and tune) causal tree 7.995966672897339 seconds ---
# Additional visits: 8675.50202962237
# Additional visits: 8640.325749207334
# Additional visits: 8597.580645686388
# --- Time to fit (and tune) causal tree 0.8043022155761719 seconds ---
# Additional visits: 8396.086430957388
# Additional visits: 8948.43815474475
# Additional visits: 8699.277404122815
# --- Time to fit (and tune) causal tree 0.03670001029968262 seconds ---
# --- Time to fit (and tune) causal tree 0.08869624137878418 seconds ---
# --- Time to fit (and tune) causal tree 20.04704236984253 seconds ---
# Additional visits: 7394.25575671443
# --- Time to fit (and tune) causal tree 7.679598093032837 seconds ---
# --- Time to fit (and tune) causal tree 0.23836517333984375 seconds ---
# --- Time to fit (and tune) causal tree 2.7519989013671875 seconds ---
# Additional visits: 7451.075706249438
# Additional visits: 8215.23248067349
# Additional visits: 6069.289879971884
# --- Time to fit (and tune) causal tree 0.7204437255859375 seconds ---
# --- Time to fit (and tune) causal tree 18.899605989456177 seconds ---
# Additional visits: 8508.200066295538
# Additional visits: 8457.208101274668
# --- Time to fit (and tune) causal tree 2.361093282699585 seconds ---
# --- Time to fit (and tune) causal tree 0.03654766082763672 seconds ---
# Additional visits: 8378.69077431945
# --- Time to fit (and tune) causal tree 7.051536560058594 seconds ---
# Additional visits: 8763.017384618473
# --- Time to fit (and tune) causal tree 0.08286476135253906 seconds ---
# Additional visits: 8572.079696894785
# --- Time to fit (and tune) causal tree 0.244187593460083 seconds ---
# --- Time to fit (and tune) causal tree 0.7799272537231445 seconds ---
# Additional visits: 8539.484148891775
# Additional visits: 8429.556502809852
# Additional visits: 8480.158314145636
# Additional visits: 8686.624823775144
# Additional visits: 8478.677119993965
# --- Time to fit (and tune) causal tree 0.03580021858215332 seconds ---
# --- Time to fit (and tune) causal tree 19.9488787651062 seconds ---
# --- Time to fit (and tune) causal tree 0.08392953872680664 seconds ---
# --- Time to fit (and tune) causal tree 7.114620685577393 seconds ---
# Additional visits: 8463.221528867147
# --- Time to fit (and tune) causal tree 0.24091577529907227 seconds ---
# --- Time to fit (and tune) causal tree 2.744673252105713 seconds ---
# Additional visits: 8375.044613192738
# Additional visits: 8415.37388021435
# Additional visits: 8844.751075772021
# Additional visits: 8129.676932307334
# --- Time to fit (and tune) causal tree 0.7418603897094727 seconds ---
# Additional visits: 8204.018766379053
# Additional visits: 8804.73758648495
# --- Time to fit (and tune) causal tree 0.036475181579589844 seconds ---
# Additional visits: 8577.053169610173
# --- Time to fit (and tune) causal tree 0.0852057933807373 seconds ---
# --- Time to fit (and tune) causal tree 0.2362229824066162 seconds ---
# --- Time to fit (and tune) causal tree 2.524137496948242 seconds ---
# Additional visits: 8577.797765487105
# --- Time to fit (and tune) causal tree 8.150623083114624 seconds ---
# --- Time to fit (and tune) causal tree 0.8954086303710938 seconds ---
# Additional visits: 8024.746892398601
# --- Time to fit (and tune) causal tree 24.276390552520752 seconds ---
# Additional visits: 8649.71313207408
# Additional visits: 7735.740802737176
# Additional visits: 8518.560086471054
# Additional visits: 8590.1911030239
# Additional visits: 8906.45644023861
# --- Time to fit (and tune) causal tree 20.265392303466797 seconds ---
# --- Time to fit (and tune) causal tree 0.037671804428100586 seconds ---
# --- Time to fit (and tune) causal tree 0.08584356307983398 seconds ---
# --- Time to fit (and tune) causal tree 0.23682141304016113 seconds ---
# Additional visits: 8386.57129973733
# --- Time to fit (and tune) causal tree 2.850604772567749 seconds ---
# --- Time to fit (and tune) causal tree 8.54456114768982 seconds ---
# --- Time to fit (and tune) causal tree 0.8916120529174805 seconds ---
# Additional visits: 8905.652429776306
# --- Time to fit (and tune) causal tree 18.113718032836914 seconds ---
# Additional visits: 8391.263325553047
# Additional visits: 8422.423653973188
# Additional visits: 8790.483001034947
# --- Time to fit (and tune) causal tree 0.03644704818725586 seconds ---
# --- Time to fit (and tune) causal tree 2.440028667449951 seconds ---
# Additional visits: 8878.837962504376
# --- Time to fit (and tune) causal tree 0.08371686935424805 seconds ---
# Additional visits: 8441.667542637444
# --- Time to fit (and tune) causal tree 7.3832008838653564 seconds ---
# --- Time to fit (and tune) causal tree 0.23004603385925293 seconds ---
# Additional visits: 7852.298216509842
# Additional visits: 2450.237926110179
# Additional visits: 8303.102902358247
# Additional visits: 8565.221778303485
# Additional visits: 8830.294237988237
# --- Time to fit (and tune) causal tree 0.8146088123321533 seconds ---
# --- Time to fit (and tune) causal tree 0.03662681579589844 seconds ---
# Additional visits: 8646.78803105879
# Additional visits: 8828.40996066835
# --- Time to fit (and tune) causal tree 0.08001852035522461 seconds ---
# --- Time to fit (and tune) causal tree 7.3058271408081055 seconds ---
# --- Time to fit (and tune) causal tree 2.3837363719940186 seconds ---
# --- Time to fit (and tune) causal tree 0.24010586738586426 seconds ---
# Additional visits: 8644.357711434535
# --- Time to fit (and tune) causal tree 22.50324583053589 seconds ---
# Additional visits: 8925.314608353685
# Additional visits: 8762.45997908732
# --- Time to fit (and tune) causal tree 0.7766284942626953 seconds ---
# Additional visits: 5479.867134643229
# --- Time to fit (and tune) causal tree 21.08372402191162 seconds ---
# Additional visits: 8499.511100092437
# --- Time to fit (and tune) causal tree 2.5148122310638428 seconds ---
# Additional visits: 8709.369776738247
# --- Time to fit (and tune) causal tree 0.0381317138671875 seconds ---
# Additional visits: 8851.793507642136
# --- Time to fit (and tune) causal tree 0.0812528133392334 seconds ---
# Additional visits: 8453.433441622274
# --- Time to fit (and tune) causal tree 0.26183533668518066 seconds ---
# --- Time to fit (and tune) causal tree 7.320575952529907 seconds ---
# --- Time to fit (and tune) causal tree 0.846327543258667 seconds ---
# Additional visits: 8765.30107478882
# Additional visits: 8693.462363726121
# Additional visits: 7647.0694114981825
# Additional visits: 9012.084284578756
# --- Time to fit (and tune) causal tree 20.486453771591187 seconds ---
# --- Time to fit (and tune) causal tree 0.03792262077331543 seconds ---
# Additional visits: 8369.650042947182
# --- Time to fit (and tune) causal tree 0.08876752853393555 seconds ---
# --- Time to fit (and tune) causal tree 8.05355167388916 seconds ---
# --- Time to fit (and tune) causal tree 2.5851845741271973 seconds ---
# Additional visits: 8617.559225257282
# Additional visits: 8251.18460264414
# Additional visits: 8214.60630246572
# --- Time to fit (and tune) causal tree 0.23383331298828125 seconds ---
# --- Time to fit (and tune) causal tree 0.8553287982940674 seconds ---
# Additional visits: 8476.300647232536
# Additional visits: 8775.404073375546
# Additional visits: 8806.319140191075
# Additional visits: 8652.801279526726
# --- Time to fit (and tune) causal tree 0.036657094955444336 seconds ---
# Additional visits: 8429.423538934463
# --- Time to fit (and tune) causal tree 0.0851590633392334 seconds ---
# --- Time to fit (and tune) causal tree 2.513254165649414 seconds ---
# --- Time to fit (and tune) causal tree 0.24559259414672852 seconds ---
# --- Time to fit (and tune) causal tree 21.856946229934692 seconds ---
# Additional visits: 8535.860581124289
# --- Time to fit (and tune) causal tree 8.095273971557617 seconds ---
# Additional visits: 8243.17258990868
# Additional visits: 8970.979319659356
# --- Time to fit (and tune) causal tree 0.815831184387207 seconds ---
# --- Time to fit (and tune) causal tree 19.703105688095093 seconds ---
# Additional visits: 8760.916486690818
# Additional visits: 7921.492951458232
# Additional visits: 8182.315023313849
# Additional visits: 8335.318182635105
# --- Time to fit (and tune) causal tree 0.03583359718322754 seconds ---
# --- Time to fit (and tune) causal tree 0.08266949653625488 seconds ---
# --- Time to fit (and tune) causal tree 0.24359798431396484 seconds ---
# Additional visits: 8369.256637453875
# --- Time to fit (and tune) causal tree 2.417966604232788 seconds ---
# --- Time to fit (and tune) causal tree 7.6069252490997314 seconds ---
# --- Time to fit (and tune) causal tree 0.7334251403808594 seconds ---
# Additional visits: 8543.811971620968
# Additional visits: 9069.790202814671
# Additional visits: 8521.18007107702
# Additional visits: 8314.877313458599
# --- Time to fit (and tune) causal tree 0.03730058670043945 seconds ---
# Additional visits: 8348.813330251394
# --- Time to fit (and tune) causal tree 2.5675344467163086 seconds ---
# Additional visits: 8635.809122750989
# Additional visits: 8694.096509061756
# --- Time to fit (and tune) causal tree 0.08376193046569824 seconds ---
# --- Time to fit (and tune) causal tree 0.24899792671203613 seconds ---
# --- Time to fit (and tune) causal tree 8.037361145019531 seconds ---
# --- Time to fit (and tune) causal tree 23.47131323814392 seconds ---
# --- Time to fit (and tune) causal tree 0.7971839904785156 seconds ---
# Additional visits: 8496.652712061732
# Additional visits: 8652.881036275652
# Additional visits: 8573.555159973372
# Additional visits: 8683.96369475854
# --- Time to fit (and tune) causal tree 0.03672337532043457 seconds ---
# Additional visits: 8419.827618859077
# Additional visits: 7835.7657329902795
# --- Time to fit (and tune) causal tree 0.08792543411254883 seconds ---
# --- Time to fit (and tune) causal tree 7.0156519412994385 seconds ---
# --- Time to fit (and tune) causal tree 2.309366464614868 seconds ---
# --- Time to fit (and tune) causal tree 21.679481029510498 seconds ---
# --- Time to fit (and tune) causal tree 0.24871516227722168 seconds ---
# Additional visits: 8564.575481458756
# Additional visits: 8615.381677882757
# Additional visits: 8680.400703733958
# --- Time to fit (and tune) causal tree 0.7983062267303467 seconds ---
# Additional visits: 8358.909461365687
# --- Time to fit (and tune) causal tree 19.910277128219604 seconds ---
# --- Time to fit (and tune) causal tree 6.2253172397613525 seconds ---
# Additional visits: 7873.6325115143
# Additional visits: 8780.21944599604
# --- Time to fit (and tune) causal tree 0.03827190399169922 seconds ---
# --- Time to fit (and tune) causal tree 2.368964672088623 seconds ---
# --- Time to fit (and tune) causal tree 0.0878438949584961 seconds ---
# Additional visits: 8329.82204132964
# Additional visits: 8547.836605038607
# --- Time to fit (and tune) causal tree 0.24866557121276855 seconds ---
# Additional visits: 8685.185046054625
# --- Time to fit (and tune) causal tree 0.7706036567687988 seconds ---
# Additional visits: 8522.453680732826
# Additional visits: 8916.242346541712
# Additional visits: 8544.380681293094
# --- Time to fit (and tune) causal tree 0.03695964813232422 seconds ---
# --- Time to fit (and tune) causal tree 6.591599941253662 seconds ---
# Additional visits: 8734.688463181763
# Additional visits: 8470.719766657421
# --- Time to fit (and tune) causal tree 0.08351349830627441 seconds ---
# --- Time to fit (and tune) causal tree 2.639195203781128 seconds ---
# --- Time to fit (and tune) causal tree 0.23075294494628906 seconds ---
# Additional visits: 8874.158186979434
# Additional visits: 8553.145600545535
# Additional visits: 8511.457888413457
# --- Time to fit (and tune) causal tree 23.22422695159912 seconds ---
# Additional visits: 8672.272278065351
# Additional visits: 8520.503783062823
# --- Time to fit (and tune) causal tree 0.823678731918335 seconds ---
# --- Time to fit (and tune) causal tree 19.26670527458191 seconds ---
# --- Time to fit (and tune) causal tree 0.03865408897399902 seconds ---
# Additional visits: 8654.220281870517
# --- Time to fit (and tune) causal tree 0.08338451385498047 seconds ---
# Additional visits: 8800.980880699619
# --- Time to fit (and tune) causal tree 2.5671546459198 seconds ---
# --- Time to fit (and tune) causal tree 0.25312209129333496 seconds ---
# --- Time to fit (and tune) causal tree 6.733793258666992 seconds ---
# Additional visits: 8404.129786738098
# --- Time to fit (and tune) causal tree 17.929041385650635 seconds ---
# Additional visits: 3643.0831156634763
# --- Time to fit (and tune) causal tree 0.7639896869659424 seconds ---
# Additional visits: 8374.523762481043
# Additional visits: 8717.391660860334
# Additional visits: 8087.376233991863
# --- Time to fit (and tune) causal tree 0.03714942932128906 seconds ---
# Additional visits: 8624.795301598582
# --- Time to fit (and tune) causal tree 2.4369966983795166 seconds ---
# --- Time to fit (and tune) causal tree 0.0840311050415039 seconds ---
# --- Time to fit (and tune) causal tree 7.509304761886597 seconds ---
# Additional visits: 7960.118017032381
# --- Time to fit (and tune) causal tree 0.24045443534851074 seconds ---
# Additional visits: 8763.192896933962
# Additional visits: 8606.008358422117
# Additional visits: 8602.802817752541
# --- Time to fit (and tune) causal tree 19.471248865127563 seconds ---
# Additional visits: 8585.493412846088
# Additional visits: 8418.013989969424
# --- Time to fit (and tune) causal tree 0.7701458930969238 seconds ---
# Additional visits: 8798.044067237164
# --- Time to fit (and tune) causal tree 0.03799891471862793 seconds ---
# --- Time to fit (and tune) causal tree 0.08680367469787598 seconds ---
# Additional visits: 8628.75829224275
# Additional visits: 8668.905542346381
# --- Time to fit (and tune) causal tree 7.474919080734253 seconds ---
# --- Time to fit (and tune) causal tree 2.489668369293213 seconds ---
# --- Time to fit (and tune) causal tree 0.26488542556762695 seconds ---
# --- Time to fit (and tune) causal tree 0.8540477752685547 seconds ---
# Additional visits: 8279.44908932336
# --- Time to fit (and tune) causal tree 17.467925548553467 seconds ---
# Additional visits: 8345.740939038487
# Additional visits: 8268.670983963004
# Additional visits: 8673.403752161868
# Additional visits: 8851.306220264512
# --- Time to fit (and tune) causal tree 0.03649115562438965 seconds ---
# --- Time to fit (and tune) causal tree 0.07979607582092285 seconds ---
# Additional visits: 8478.270283625257
# --- Time to fit (and tune) causal tree 2.787346839904785 seconds ---
# --- Time to fit (and tune) causal tree 0.2213277816772461 seconds ---
# --- Time to fit (and tune) causal tree 7.482470273971558 seconds ---
# Additional visits: 8115.6902394601775
# Additional visits: 8621.53035690111
# --- Time to fit (and tune) causal tree 0.7987022399902344 seconds ---
# Additional visits: 5731.972241526957
# Additional visits: 8731.375463343224
# Additional visits: 8348.693786390388
# --- Time to fit (and tune) causal tree 0.03695511817932129 seconds ---
# Additional visits: 8507.14829856698
# Additional visits: 8871.423080821789
# --- Time to fit (and tune) causal tree 0.0871891975402832 seconds ---
# --- Time to fit (and tune) causal tree 0.24913763999938965 seconds ---
# --- Time to fit (and tune) causal tree 2.2225754261016846 seconds ---
# Additional visits: 8776.252818808594
# Additional visits: 8873.623950978772
# --- Time to fit (and tune) causal tree 8.036163330078125 seconds ---
# --- Time to fit (and tune) causal tree 22.604448080062866 seconds ---
# --- Time to fit (and tune) causal tree 0.789243221282959 seconds ---
# Additional visits: 8630.124386166108
# Additional visits: 8528.026951870503
# --- Time to fit (and tune) causal tree 19.260535717010498 seconds ---
# Additional visits: 8432.233647214323
# Additional visits: 8318.700137031063
# --- Time to fit (and tune) causal tree 2.449643135070801 seconds ---
# Additional visits: 8380.073911656476
# --- Time to fit (and tune) causal tree 0.03866076469421387 seconds ---
# --- Time to fit (and tune) causal tree 0.07891106605529785 seconds ---
# Additional visits: 8175.752492418808
# --- Time to fit (and tune) causal tree 0.2511134147644043 seconds ---
# --- Time to fit (and tune) causal tree 7.322338342666626 seconds ---
# --- Time to fit (and tune) causal tree 0.8276493549346924 seconds ---
# Additional visits: 8171.91527071808
# Additional visits: 8402.799501115285
# Additional visits: 8406.672233344607
# Additional visits: 5143.169253054036
# --- Time to fit (and tune) causal tree 20.377954483032227 seconds ---
# --- Time to fit (and tune) causal tree 0.038193464279174805 seconds ---
# Additional visits: 8597.415062551165
# --- Time to fit (and tune) causal tree 0.08369636535644531 seconds ---
# Additional visits: 7003.909235472795
# --- Time to fit (and tune) causal tree 2.8018507957458496 seconds ---
# --- Time to fit (and tune) causal tree 7.454251289367676 seconds ---
# --- Time to fit (and tune) causal tree 0.2521040439605713 seconds ---
# Additional visits: 8607.100947168146
# Additional visits: 8660.482247708933
# Additional visits: 8771.44072216127
# --- Time to fit (and tune) causal tree 0.8106532096862793 seconds ---
# Additional visits: 7261.197264171358
# Additional visits: 8341.725596764169
# --- Time to fit (and tune) causal tree 0.03746843338012695 seconds ---
# Additional visits: 8373.510648863961
# --- Time to fit (and tune) causal tree 2.4391212463378906 seconds ---
# --- Time to fit (and tune) causal tree 0.0837850570678711 seconds ---
# Additional visits: 9002.610458472485
# --- Time to fit (and tune) causal tree 21.494344234466553 seconds ---
# --- Time to fit (and tune) causal tree 0.23349380493164062 seconds ---
# Additional visits: 8481.449609493098
# --- Time to fit (and tune) causal tree 8.363959550857544 seconds ---
# Additional visits: 8662.659750715591
# --- Time to fit (and tune) causal tree 18.957209587097168 seconds ---
# --- Time to fit (and tune) causal tree 0.7955615520477295 seconds ---
# Additional visits: 7585.833621568913
# Additional visits: 8690.453842571469
# Additional visits: 8577.197595327976
# Additional visits: 8358.459638779394
# Additional visits: 8188.793041891556
# --- Time to fit (and tune) causal tree 0.03770756721496582 seconds ---
# --- Time to fit (and tune) causal tree 0.08409237861633301 seconds ---
# --- Time to fit (and tune) causal tree 0.2518770694732666 seconds ---
# --- Time to fit (and tune) causal tree 2.2745776176452637 seconds ---
# Additional visits: 8299.768456684784
# --- Time to fit (and tune) causal tree 7.758267641067505 seconds ---
# Additional visits: 8676.027742113998
# --- Time to fit (and tune) causal tree 0.7682390213012695 seconds ---
# Additional visits: 8664.236782188216
# Additional visits: 8809.373673543218
# Additional visits: 8218.58628716291
# --- Time to fit (and tune) causal tree 0.037732839584350586 seconds ---
# --- Time to fit (and tune) causal tree 6.443396091461182 seconds ---
# --- Time to fit (and tune) causal tree 2.7719900608062744 seconds ---
# Additional visits: 8822.958160366485
# --- Time to fit (and tune) causal tree 21.49329686164856 seconds ---
# Additional visits: 8114.495686404171
# --- Time to fit (and tune) causal tree 0.08569073677062988 seconds ---
# Additional visits: 8663.301179522554
# --- Time to fit (and tune) causal tree 0.2568695545196533 seconds ---
# --- Time to fit (and tune) causal tree 0.73333740234375 seconds ---
# Additional visits: 8723.43480388515
# Additional visits: 8761.900955284973
# Additional visits: 8485.63554030891
# Additional visits: 8606.564418756177
# --- Time to fit (and tune) causal tree 0.03747057914733887 seconds ---
# --- Time to fit (and tune) causal tree 20.464102268218994 seconds ---
# Additional visits: 8656.672983403198
# Additional visits: 8202.5280341179
# --- Time to fit (and tune) causal tree 2.4411370754241943 seconds ---
# --- Time to fit (and tune) causal tree 0.08721613883972168 seconds ---
# --- Time to fit (and tune) causal tree 0.24976348876953125 seconds ---
# Additional visits: 8273.24830479903
# --- Time to fit (and tune) causal tree 8.028578281402588 seconds ---
# Additional visits: 8041.596418459435
# Additional visits: 8676.878192901959
# --- Time to fit (and tune) causal tree 0.7788641452789307 seconds ---
# Additional visits: 8761.030739030348
# Additional visits: 8371.036848892196
# --- Time to fit (and tune) causal tree 19.51638960838318 seconds ---
# --- Time to fit (and tune) causal tree 0.038054704666137695 seconds ---
# Additional visits: 8639.640500083202
# Additional visits: 8816.024453851394
# --- Time to fit (and tune) causal tree 0.08589673042297363 seconds ---
# --- Time to fit (and tune) causal tree 7.402555465698242 seconds ---
# --- Time to fit (and tune) causal tree 0.24690937995910645 seconds ---
# --- Time to fit (and tune) causal tree 2.6848227977752686 seconds ---
# Additional visits: 8399.506636949734
# Additional visits: 8624.484191281583
# Additional visits: 8445.768063693053
# --- Time to fit (and tune) causal tree 0.7492399215698242 seconds ---
# Additional visits: 8455.712248719496
# Additional visits: 8985.617525172074
# --- Time to fit (and tune) causal tree 0.03678464889526367 seconds ---
# Additional visits: 8342.767044220345
# --- Time to fit (and tune) causal tree 2.344583749771118 seconds ---
# Additional visits: 8604.160542150103
# --- Time to fit (and tune) causal tree 0.08280754089355469 seconds ---
# Additional visits: 8367.503563779977
# --- Time to fit (and tune) causal tree 21.519596099853516 seconds ---
# --- Time to fit (and tune) causal tree 0.2381758689880371 seconds ---
# --- Time to fit (and tune) causal tree 8.710020542144775 seconds ---
# --- Time to fit (and tune) causal tree 0.7162246704101562 seconds ---
# Additional visits: 8747.321050846644
# Additional visits: 8361.235701820446
# Additional visits: 8814.170382124823
# Additional visits: 8596.458045896088
# Additional visits: 8517.977060951158
# --- Time to fit (and tune) causal tree 0.0692589282989502 seconds ---
# --- Time to fit (and tune) causal tree 0.0900120735168457 seconds ---
# Additional visits: 8353.861379920707
# --- Time to fit (and tune) causal tree 2.2709145545959473 seconds ---
# --- Time to fit (and tune) causal tree 7.681812763214111 seconds ---
# --- Time to fit (and tune) causal tree 0.23909687995910645 seconds ---
# Additional visits: 8974.287680160927
# --- Time to fit (and tune) causal tree 18.64935302734375 seconds ---
# Additional visits: 8950.079524574308
# Additional visits: 8595.596686757784
# --- Time to fit (and tune) causal tree 0.7871012687683105 seconds ---
# --- Time to fit (and tune) causal tree 23.262261629104614 seconds ---
# Additional visits: 8909.387197409354
# Additional visits: 8318.651880368176
# --- Time to fit (and tune) causal tree 0.037036895751953125 seconds ---
# --- Time to fit (and tune) causal tree 6.33288049697876 seconds ---
# --- Time to fit (and tune) causal tree 2.651491403579712 seconds ---
# Additional visits: 8443.198938772544
# Additional visits: 8864.841187740987
# Additional visits: 8195.571468693463
# --- Time to fit (and tune) causal tree 0.07800507545471191 seconds ---
# --- Time to fit (and tune) causal tree 0.24182868003845215 seconds ---
# --- Time to fit (and tune) causal tree 0.8046860694885254 seconds ---
# Additional visits: 8727.737331400507
# Additional visits: 3270.83602769048
# Additional visits: 8949.484077075227
# Additional visits: 8411.058671767798
# --- Time to fit (and tune) causal tree 20.571216344833374 seconds ---
# --- Time to fit (and tune) causal tree 0.037383079528808594 seconds ---
# --- Time to fit (and tune) causal tree 7.13577938079834 seconds ---
# --- Time to fit (and tune) causal tree 2.5462193489074707 seconds ---
# Additional visits: 6826.774147904843
# --- Time to fit (and tune) causal tree 0.08194112777709961 seconds ---
# Additional visits: 8676.4213088004
# Additional visits: 7707.802512043571
# --- Time to fit (and tune) causal tree 0.23862266540527344 seconds ---
# Additional visits: 8431.527707820334
# Additional visits: 8541.274000048961
# Additional visits: 8700.465159404981
# --- Time to fit (and tune) causal tree 0.7584958076477051 seconds ---
# Additional visits: 7965.245250446644
# Additional visits: 8321.020549514184
# --- Time to fit (and tune) causal tree 0.03785276412963867 seconds ---
# --- Time to fit (and tune) causal tree 0.08403801918029785 seconds ---
# --- Time to fit (and tune) causal tree 20.73366069793701 seconds ---
# Additional visits: 8407.48536822606
# --- Time to fit (and tune) causal tree 2.298967123031616 seconds ---
# --- Time to fit (and tune) causal tree 7.119635343551636 seconds ---
# --- Time to fit (and tune) causal tree 0.24313950538635254 seconds ---
# Additional visits: 8983.199680913158
# Additional visits: 351.95179067769016
# --- Time to fit (and tune) causal tree 18.80836057662964 seconds ---
# Additional visits: 8697.12200570541
# Additional visits: 7699.982316842142
# Additional visits: 8477.294212565332
# --- Time to fit (and tune) causal tree 0.806560754776001 seconds ---
# Additional visits: 8226.53987201238
# Additional visits: 8960.71853785395
# --- Time to fit (and tune) causal tree 0.036817073822021484 seconds ---
# --- Time to fit (and tune) causal tree 0.08306503295898438 seconds ---
# --- Time to fit (and tune) causal tree 6.330648183822632 seconds ---
# --- Time to fit (and tune) causal tree 0.24086356163024902 seconds ---
# --- Time to fit (and tune) causal tree 2.9365382194519043 seconds ---
# Additional visits: 6920.009768094451
# Additional visits: 8375.544926694449
# Additional visits: 8711.022916532243
# --- Time to fit (and tune) causal tree 0.7453453540802002 seconds ---
# Additional visits: 8088.325841646803
# Additional visits: 8594.508199142156
# --- Time to fit (and tune) causal tree 0.03733706474304199 seconds ---
# Additional visits: 8733.37155111288
# Additional visits: 8064.265156781353
# Additional visits: 8436.361739215192
# --- Time to fit (and tune) causal tree 21.333592891693115 seconds ---
# --- Time to fit (and tune) causal tree 0.08364701271057129 seconds ---
# --- Time to fit (and tune) causal tree 2.573087692260742 seconds ---
# --- Time to fit (and tune) causal tree 0.2486271858215332 seconds ---
# --- Time to fit (and tune) causal tree 0.816155195236206 seconds ---
# --- Time to fit (and tune) causal tree 8.316529512405396 seconds ---
# Additional visits: 8917.503674513315
# Additional visits: 8647.478346194297
# Additional visits: 7587.050931105139
# Additional visits: 8165.4227713282235
# Additional visits: 8570.406590596038
# --- Time to fit (and tune) causal tree 0.03621959686279297 seconds ---
# --- Time to fit (and tune) causal tree 0.08522319793701172 seconds ---
# --- Time to fit (and tune) causal tree 19.96833872795105 seconds ---
# Additional visits: 8574.592782408141
# --- Time to fit (and tune) causal tree 2.692593574523926 seconds ---
# --- Time to fit (and tune) causal tree 0.24558162689208984 seconds ---
# Additional visits: 8659.610820343236
# --- Time to fit (and tune) causal tree 17.31183648109436 seconds ---
# --- Time to fit (and tune) causal tree 7.731173515319824 seconds ---
# --- Time to fit (and tune) causal tree 0.7978610992431641 seconds ---
# Additional visits: 8639.216557620231
# Additional visits: 8027.06691135073
# Additional visits: 8613.826622954222
# Additional visits: 8237.130941547297
# --- Time to fit (and tune) causal tree 0.037792205810546875 seconds ---
# Additional visits: 8479.600825360281
# Additional visits: 8337.775507764174
# --- Time to fit (and tune) causal tree 0.08431220054626465 seconds ---
# --- Time to fit (and tune) causal tree 2.741834878921509 seconds ---
# Additional visits: 8483.066597881761
# --- Time to fit (and tune) causal tree 0.2518777847290039 seconds ---
# --- Time to fit (and tune) causal tree 7.9288671016693115 seconds ---
# --- Time to fit (and tune) causal tree 0.7805962562561035 seconds ---
# Additional visits: 8254.426020064073
# Additional visits: 8566.658237379897
# Additional visits: 8400.231068024388
# Additional visits: 8751.131007720092
# Additional visits: 8678.881908384092
# --- Time to fit (and tune) causal tree 0.03814959526062012 seconds ---
# Additional visits: 8934.985179921434
# Additional visits: 8927.151726361155
# --- Time to fit (and tune) causal tree 0.08325910568237305 seconds ---
# --- Time to fit (and tune) causal tree 0.24219489097595215 seconds ---
# --- Time to fit (and tune) causal tree 21.49688220024109 seconds ---
# --- Time to fit (and tune) causal tree 2.578911542892456 seconds ---
# --- Time to fit (and tune) causal tree 7.874363899230957 seconds ---
# --- Time to fit (and tune) causal tree 0.8319821357727051 seconds ---
# Additional visits: 8446.680378703806
# Additional visits: 8530.362568931965
# Additional visits: 8389.576897293751
# Additional visits: 8328.394080639177
# --- Time to fit (and tune) causal tree 0.03812861442565918 seconds ---
# Additional visits: 8619.57959448321
# --- Time to fit (and tune) causal tree 2.7076995372772217 seconds ---
# --- Time to fit (and tune) causal tree 0.08467531204223633 seconds ---
# Additional visits: 8255.126015650663
# --- Time to fit (and tune) causal tree 0.32167983055114746 seconds ---
# Additional visits: 8925.800933376064
# --- Time to fit (and tune) causal tree 7.565373182296753 seconds ---
# --- Time to fit (and tune) causal tree 0.8175082206726074 seconds ---
# Additional visits: 8991.130238645055
# Additional visits: 7659.007815513169
# Additional visits: 8161.788780253617
# --- Time to fit (and tune) causal tree 24.024169921875 seconds ---
# --- Time to fit (and tune) causal tree 20.41104483604431 seconds ---
# Additional visits: 7536.407256232126
# Additional visits: 8471.98540911286
# --- Time to fit (and tune) causal tree 0.03741025924682617 seconds ---
# --- Time to fit (and tune) causal tree 0.08398818969726562 seconds ---
# Additional visits: 8639.751246629628
# --- Time to fit (and tune) causal tree 2.44415020942688 seconds ---
# --- Time to fit (and tune) causal tree 0.23154830932617188 seconds ---
# Additional visits: 7843.226820947423
# --- Time to fit (and tune) causal tree 7.903779983520508 seconds ---
# Additional visits: 7808.371171174696
# --- Time to fit (and tune) causal tree 0.7932279109954834 seconds ---
# Additional visits: 8039.7851190833135
# Additional visits: 5281.118077553749
# Additional visits: 7649.972392205385
# Additional visits: 7730.5034717152685
# --- Time to fit (and tune) causal tree 0.03884100914001465 seconds ---
# --- Time to fit (and tune) causal tree 0.08564901351928711 seconds ---
# --- Time to fit (and tune) causal tree 2.699636936187744 seconds ---
# --- Time to fit (and tune) causal tree 7.640347957611084 seconds ---
# Additional visits: 8401.714044509152
# --- Time to fit (and tune) causal tree 0.22775840759277344 seconds ---
# Additional visits: 8845.729522125814
# --- Time to fit (and tune) causal tree 18.35348892211914 seconds ---
# Additional visits: 8648.638204315712
# --- Time to fit (and tune) causal tree 25.075150966644287 seconds ---
# Additional visits: 8635.080231283102
# Additional visits: 8736.336359284669
# --- Time to fit (and tune) causal tree 0.7482092380523682 seconds ---
# Additional visits: 8320.341134058195
# Additional visits: 8353.490909574602
# --- Time to fit (and tune) causal tree 0.047677040100097656 seconds ---
# --- Time to fit (and tune) causal tree 0.08200335502624512 seconds ---
# Additional visits: 8544.844742432817
# --- Time to fit (and tune) causal tree 0.25263333320617676 seconds ---
# --- Time to fit (and tune) causal tree 2.419656991958618 seconds ---
# --- Time to fit (and tune) causal tree 8.169933557510376 seconds ---
# Additional visits: 8527.613491748492
# Additional visits: 8277.063444299925
# Additional visits: 8598.03969515543
# --- Time to fit (and tune) causal tree 0.8113515377044678 seconds ---
# Additional visits: 8708.06847051152
# Additional visits: 8313.762920755895
# Additional visits: 8570.12595034383
# --- Time to fit (and tune) causal tree 0.036537885665893555 seconds ---
# --- Time to fit (and tune) causal tree 21.62487268447876 seconds ---
# --- Time to fit (and tune) causal tree 0.08591747283935547 seconds ---
# --- Time to fit (and tune) causal tree 2.4890263080596924 seconds ---
# Additional visits: 8472.255971208775
# --- Time to fit (and tune) causal tree 7.47407865524292 seconds ---
# Additional visits: 8449.40227847287
# --- Time to fit (and tune) causal tree 0.2438521385192871 seconds ---
# --- Time to fit (and tune) causal tree 0.8121256828308105 seconds ---
# Additional visits: 8692.04119662413
# Additional visits: 8545.84638577746
# Additional visits: 8541.51076086182
# Additional visits: 7962.904986863762
# Additional visits: 8438.671321402504
# --- Time to fit (and tune) causal tree 0.03851747512817383 seconds ---
# --- Time to fit (and tune) causal tree 0.1366889476776123 seconds ---
# Additional visits: 8444.790507024498
# --- Time to fit (and tune) causal tree 0.2392892837524414 seconds ---
# --- Time to fit (and tune) causal tree 2.7950780391693115 seconds ---
# --- Time to fit (and tune) causal tree 8.134695053100586 seconds ---
# Additional visits: 8482.536727891047
# Additional visits: 8626.83872836044
# --- Time to fit (and tune) causal tree 0.7687156200408936 seconds ---
# --- Time to fit (and tune) causal tree 25.253939867019653 seconds ---
# Additional visits: 8520.97077710696
# Additional visits: 8179.467442230402
# Additional visits: 8643.74059709008
# Additional visits: 8546.169448012191
# Additional visits: 8284.13438106762
# --- Time to fit (and tune) causal tree 0.03643465042114258 seconds ---
# --- Time to fit (and tune) causal tree 0.0877833366394043 seconds ---
# --- Time to fit (and tune) causal tree 0.24706459045410156 seconds ---
# --- Time to fit (and tune) causal tree 21.868165254592896 seconds ---
# --- Time to fit (and tune) causal tree 2.574296712875366 seconds ---
# Additional visits: 8378.788395519981
# --- Time to fit (and tune) causal tree 7.514492034912109 seconds ---
# --- Time to fit (and tune) causal tree 0.806039571762085 seconds ---
# Additional visits: 8631.23944161402
# Additional visits: 7796.554568567015
# Additional visits: 9099.08955021834
# Additional visits: 8642.583555202742
# Additional visits: 8629.642293797111
# --- Time to fit (and tune) causal tree 0.0365755558013916 seconds ---
# --- Time to fit (and tune) causal tree 0.08441662788391113 seconds ---
# Additional visits: 8509.027273764772
# --- Time to fit (and tune) causal tree 2.451232671737671 seconds ---
# --- Time to fit (and tune) causal tree 0.23392605781555176 seconds ---
# --- Time to fit (and tune) causal tree 7.3909406661987305 seconds ---
# --- Time to fit (and tune) causal tree 22.926891565322876 seconds ---
# --- Time to fit (and tune) causal tree 17.903579711914062 seconds ---
# Additional visits: 8590.784568660472
# Additional visits: 8477.885261384627
# Additional visits: 8775.637622392056
# Additional visits: 8629.957714850183
# --- Time to fit (and tune) causal tree 0.7319798469543457 seconds ---
# Additional visits: 8153.809099825722
# Additional visits: 8424.84104484009
# --- Time to fit (and tune) causal tree 0.03755807876586914 seconds ---
# Additional visits: 8490.217370078126
# --- Time to fit (and tune) causal tree 0.08379888534545898 seconds ---
# --- Time to fit (and tune) causal tree 0.22778534889221191 seconds ---
# --- Time to fit (and tune) causal tree 7.1157026290893555 seconds ---
# --- Time to fit (and tune) causal tree 2.4407691955566406 seconds ---
# Additional visits: 8303.54011025482
# --- Time to fit (and tune) causal tree 19.05144214630127 seconds ---
# --- Time to fit (and tune) causal tree 0.7517240047454834 seconds ---
# Additional visits: 8693.180422904241
# Additional visits: 8499.640388325024
# Additional visits: 8856.87065091176
# Additional visits: 8275.14640447326
# Additional visits: 8700.564876618939
# --- Time to fit (and tune) causal tree 0.03722262382507324 seconds ---
# --- Time to fit (and tune) causal tree 0.08736348152160645 seconds ---
# Additional visits: 8052.664522679475
# --- Time to fit (and tune) causal tree 6.9544055461883545 seconds ---
# Additional visits: 8833.420170250727
# --- Time to fit (and tune) causal tree 2.467514753341675 seconds ---
# Additional visits: 8662.260739243562
# --- Time to fit (and tune) causal tree 0.24823880195617676 seconds ---
# --- Time to fit (and tune) causal tree 0.848963737487793 seconds ---
# Additional visits: 8570.14346564726
# Additional visits: 8519.675662913502
# Additional visits: 8600.420378721397
# Additional visits: 8389.248200214966
# --- Time to fit (and tune) causal tree 2.311971426010132 seconds ---
# --- Time to fit (and tune) causal tree 0.03807878494262695 seconds ---
# --- Time to fit (and tune) causal tree 0.08969712257385254 seconds ---
# Additional visits: 8622.417828804719
# --- Time to fit (and tune) causal tree 0.24536991119384766 seconds ---
# --- Time to fit (and tune) causal tree 7.189178705215454 seconds ---
# Additional visits: 8908.215029165516
# Additional visits: 8443.928295775895
# --- Time to fit (and tune) causal tree 18.266489267349243 seconds ---
# --- Time to fit (and tune) causal tree 23.659748554229736 seconds ---
# --- Time to fit (and tune) causal tree 0.78578782081604 seconds ---
# Additional visits: 8600.827890900062
# Additional visits: 8395.228878824455
# Additional visits: 8149.237363775564
# Additional visits: 8629.744609472586
# Additional visits: 8076.71296566167
# --- Time to fit (and tune) causal tree 0.036957502365112305 seconds ---
# --- Time to fit (and tune) causal tree 0.08493757247924805 seconds ---
# --- Time to fit (and tune) causal tree 2.3624141216278076 seconds ---
# ...
# --- Time to fit (and tune) causal tree 0.03740644454956055 seconds ---
# --- Time to fit (and tune) causal tree 0.08464360237121582 seconds ---
# Additional visits: 8557.278496098406
# --- Time to fit (and tune) causal tree 7.000434637069702 seconds ---
# --- Time to fit (and tune) causal tree 0.2654542922973633 seconds ---
# --- Time to fit (and tune) causal tree 2.486356019973755 seconds ---
# Additional visits: 8701.715897772177
# Additional visits: 8444.16830373805
# Additional visits: 8771.880188127407
# --- Time to fit (and tune) causal tree 0.7470986843109131 seconds ---
# Additional visits: 8392.201966761362
# Additional visits: 7668.522145911262
# --- Time to fit (and tune) causal tree 0.037262678146362305 seconds ---
# Additional visits: 8402.842004502303
# --- Time to fit (and tune) causal tree 0.08298707008361816 seconds ---
# --- Time to fit (and tune) causal tree 2.3622658252716064 seconds ---
# Additional visits: 7539.700021245467
# --- Time to fit (and tune) causal tree 7.550176382064819 seconds ---
# --- Time to fit (and tune) causal tree 22.85706067085266 seconds ---
# --- Time to fit (and tune) causal tree 0.24315929412841797 seconds ---
# Additional visits: 8493.432341178479
# Additional visits: 8655.67946213631
# Additional visits: 8828.312027841292
# Additional visits: 8439.583549314983
# Additional visits: 8776.581600339894
# --- Time to fit (and tune) causal tree 0.03708958625793457 seconds ---
# Additional visits: 8312.534324012011
# --- Time to fit (and tune) causal tree 0.8408007621765137 seconds ---
# --- Time to fit (and tune) causal tree 0.08215212821960449 seconds ---
# Additional visits: 8452.926962405258
# --- Time to fit (and tune) causal tree 7.128727197647095 seconds ---
# --- Time to fit (and tune) causal tree 0.24064254760742188 seconds ---
# --- Time to fit (and tune) causal tree 2.5590388774871826 seconds ---
# Additional visits: 8231.480371243606
# Additional visits: 8686.83196479033
# Additional visits: 8524.01902203047
# --- Time to fit (and tune) causal tree 0.7182579040527344 seconds ---
# --- Time to fit (and tune) causal tree 24.32213807106018 seconds ---
# Additional visits: 8496.283374848344
# --- Time to fit (and tune) causal tree 20.621107578277588 seconds ---
# Additional visits: 8531.631130576825
# --- Time to fit (and tune) causal tree 0.03753018379211426 seconds ---
# --- Time to fit (and tune) causal tree 2.4488604068756104 seconds ---
# Additional visits: 8676.45751602974
# Additional visits: 8395.592110170435
# --- Time to fit (and tune) causal tree 0.08112907409667969 seconds ---
# Additional visits: 8533.490486635154
# --- Time to fit (and tune) causal tree 0.23558425903320312 seconds ---
# --- Time to fit (and tune) causal tree 7.901931047439575 seconds ---
# --- Time to fit (and tune) causal tree 0.7555792331695557 seconds ---
# Additional visits: 8524.884199917724
# Additional visits: 8495.457219057149
# Additional visits: 6259.495687331298
# Additional visits: 8249.768400460165
# --- Time to fit (and tune) causal tree 0.03671669960021973 seconds ---
# --- Time to fit (and tune) causal tree 6.541862964630127 seconds ---
# Additional visits: 3863.179566070532
# --- Time to fit (and tune) causal tree 0.08472514152526855 seconds ---
# --- Time to fit (and tune) causal tree 2.3648300170898438 seconds ---
# --- Time to fit (and tune) causal tree 22.00385093688965 seconds ---
# Additional visits: 8482.632567605953
# --- Time to fit (and tune) causal tree 0.2573814392089844 seconds ---
# Additional visits: 8508.60074904976
# Additional visits: 8574.031223183458
# Additional visits: 8714.125060853255
# --- Time to fit (and tune) causal tree 0.692084789276123 seconds ---
# Additional visits: 8783.573005966182
# Additional visits: 8676.009249068344
# --- Time to fit (and tune) causal tree 20.663974046707153 seconds ---
# --- Time to fit (and tune) causal tree 0.03827214241027832 seconds ---
# Additional visits: 8564.677844583766
# Additional visits: 8282.44815275459
# --- Time to fit (and tune) causal tree 0.08098459243774414 seconds ---
# --- Time to fit (and tune) causal tree 0.2445378303527832 seconds ---
# --- Time to fit (and tune) causal tree 2.2617321014404297 seconds ---
# --- Time to fit (and tune) causal tree 7.4612109661102295 seconds ---
# Additional visits: 8505.825985881154
# Additional visits: 8410.90030819336
# Additional visits: 8617.250753038346
# Additional visits: 8724.348249412438
# --- Time to fit (and tune) causal tree 0.7473995685577393 seconds ---
# --- Time to fit (and tune) causal tree 20.26076316833496 seconds ---
# Additional visits: 8449.872525417237
# Additional visits: 9203.809828931127
# --- Time to fit (and tune) causal tree 0.03476405143737793 seconds ---
# --- Time to fit (and tune) causal tree 0.08613801002502441 seconds ---
# Additional visits: 8546.612614787713
# --- Time to fit (and tune) causal tree 2.613783836364746 seconds ---
# --- Time to fit (and tune) causal tree 7.1156744956970215 seconds ---
# Additional visits: 8977.13372018041
# --- Time to fit (and tune) causal tree 17.1450035572052 seconds ---
# --- Time to fit (and tune) causal tree 0.2514231204986572 seconds ---
# --- Time to fit (and tune) causal tree 0.7292897701263428 seconds ---
# Additional visits: 8288.456761723026
# Additional visits: 8685.827365100698
# Additional visits: 8600.391983811878
# Additional visits: 8326.822843374835
# Additional visits: 8714.728240918792
# Additional visits: 8642.47994713903
# --- Time to fit (and tune) causal tree 0.03670787811279297 seconds ---
# --- Time to fit (and tune) causal tree 0.08571076393127441 seconds ---
# --- Time to fit (and tune) causal tree 0.24843978881835938 seconds ---
# --- Time to fit (and tune) causal tree 2.381535291671753 seconds ---
# --- Time to fit (and tune) causal tree 7.984868049621582 seconds ---
# Additional visits: 8319.075902063785
# Additional visits: 8486.472093821007
# --- Time to fit (and tune) causal tree 0.7769041061401367 seconds ---
# Additional visits: 8606.468403924304
# Additional visits: 8844.99830396537
# Additional visits: 8469.373262156902
# Additional visits: 8572.46272997324
# --- Time to fit (and tune) causal tree 19.543471813201904 seconds ---
# --- Time to fit (and tune) causal tree 0.03732657432556152 seconds ---
# --- Time to fit (and tune) causal tree 0.08570027351379395 seconds ---
# Additional visits: 8732.781604152722
# Additional visits: 8583.313991738554
# --- Time to fit (and tune) causal tree 0.25825071334838867 seconds ---
# Additional visits: 7769.95696120017
# --- Time to fit (and tune) causal tree 6.8015031814575195 seconds ---
# --- Time to fit (and tune) causal tree 2.6463782787323 seconds ---
# --- Time to fit (and tune) causal tree 0.8067891597747803 seconds ---
# Additional visits: 4095.028544598452
# Additional visits: 8535.741430629905
# --- Time to fit (and tune) causal tree 19.20683193206787 seconds ---
# Additional visits: 7557.361404644516
# --- Time to fit (and tune) causal tree 2.7504491806030273 seconds ---
# Additional visits: 8063.743651910515
# --- Time to fit (and tune) causal tree 0.0380861759185791 seconds ---
# Additional visits: 8612.526967106956
# --- Time to fit (and tune) causal tree 0.08851480484008789 seconds ---
# --- Time to fit (and tune) causal tree 0.24126458168029785 seconds ---
# Additional visits: 7500.383191052466
# --- Time to fit (and tune) causal tree 8.075649976730347 seconds ---
# --- Time to fit (and tune) causal tree 0.7293269634246826 seconds ---
# Additional visits: 7459.423050276506
# Additional visits: 6460.375765146524
# Additional visits: 8483.09410512512
# Additional visits: 8127.336385127382
# Additional visits: 8660.43453023964
# --- Time to fit (and tune) causal tree 0.03599739074707031 seconds ---
# Additional visits: 8336.10888608071
# --- Time to fit (and tune) causal tree 0.08384823799133301 seconds ---
# --- Time to fit (and tune) causal tree 0.25637173652648926 seconds ---
# --- Time to fit (and tune) causal tree 2.130549907684326 seconds ---
# --- Time to fit (and tune) causal tree 7.26318359375 seconds ---
# Additional visits: 8378.3040281528
# --- Time to fit (and tune) causal tree 22.334747314453125 seconds ---
# Additional visits: 7507.603343411683
# --- Time to fit (and tune) causal tree 0.800199031829834 seconds ---
# Additional visits: 5345.027946653452
# Additional visits: 8597.234339454715
# Additional visits: 8929.484910845766
# --- Time to fit (and tune) causal tree 0.03618812561035156 seconds ---
# Additional visits: 7581.460682252945
# --- Time to fit (and tune) causal tree 0.08113360404968262 seconds ---
# --- Time to fit (and tune) causal tree 2.6961381435394287 seconds ---
# Additional visits: 8264.507248076205
# Additional visits: 7943.995318275122
# --- Time to fit (and tune) causal tree 7.228766679763794 seconds ---
# --- Time to fit (and tune) causal tree 21.86388063430786 seconds ---
# --- Time to fit (and tune) causal tree 0.24199604988098145 seconds ---
# --- Time to fit (and tune) causal tree 0.831648588180542 seconds ---
# Additional visits: 8049.587249998697
# Additional visits: 8754.217010919405
# Additional visits: 8269.285183254276
# Additional visits: 8695.402990294471
# Additional visits: 8967.55852941029
# --- Time to fit (and tune) causal tree 0.03774213790893555 seconds ---
# --- Time to fit (and tune) causal tree 0.08212947845458984 seconds ---
# --- Time to fit (and tune) causal tree 20.89716076850891 seconds ---
# --- Time to fit (and tune) causal tree 2.6679370403289795 seconds ---
# Additional visits: 8499.96635352526
# --- Time to fit (and tune) causal tree 7.990229606628418 seconds ---
# Additional visits: 8137.426769930902
# --- Time to fit (and tune) causal tree 0.2493302822113037 seconds ---
# Additional visits: 8412.400806350479
# --- Time to fit (and tune) causal tree 0.779608964920044 seconds ---
# Additional visits: 8634.140254037573
# Additional visits: 8214.634790095513
# --- Time to fit (and tune) causal tree 19.71662449836731 seconds ---
# Additional visits: 8385.630592689795
# Additional visits: 8598.907676977082
# --- Time to fit (and tune) causal tree 0.03742384910583496 seconds ---
# --- Time to fit (and tune) causal tree 0.08936071395874023 seconds ---
# --- Time to fit (and tune) causal tree 2.35310435295105 seconds ---
# Additional visits: 8713.19119726085
# --- Time to fit (and tune) causal tree 8.06470012664795 seconds ---
# Additional visits: 8486.986459143422
# --- Time to fit (and tune) causal tree 0.2531728744506836 seconds ---
# Additional visits: 8520.08931248375
# Additional visits: 8344.844289370994
# --- Time to fit (and tune) causal tree 0.760669469833374 seconds ---
# --- Time to fit (and tune) causal tree 19.014148712158203 seconds ---
# Additional visits: 8878.121665980949
# Additional visits: 8417.86128941154
# Additional visits: 8500.787605523363
# --- Time to fit (and tune) causal tree 0.03574824333190918 seconds ---
# Additional visits: 8509.802410655597
# --- Time to fit (and tune) causal tree 0.08071637153625488 seconds ---
# --- Time to fit (and tune) causal tree 0.23145222663879395 seconds ---
# --- Time to fit (and tune) causal tree 2.443270683288574 seconds ---
# --- Time to fit (and tune) causal tree 7.442899942398071 seconds ---
# --- Time to fit (and tune) causal tree 18.129968643188477 seconds ---
# Additional visits: 8784.360413538683
# Additional visits: 8021.632666824081
# Additional visits: 8585.829611365916
# Additional visits: 8297.359679766847
# --- Time to fit (and tune) causal tree 0.6895456314086914 seconds ---
# Additional visits: 8852.486131661484
# Additional visits: 8777.06155976243
# Additional visits: 8478.571563174879
# --- Time to fit (and tune) causal tree 0.03742694854736328 seconds ---
# --- Time to fit (and tune) causal tree 0.08414888381958008 seconds ---
# --- Time to fit (and tune) causal tree 0.2560861110687256 seconds ---
# --- Time to fit (and tune) causal tree 2.418694496154785 seconds ---
# Additional visits: 9031.037197774242
# --- Time to fit (and tune) causal tree 7.827265739440918 seconds ---
# --- Time to fit (and tune) causal tree 0.7787091732025146 seconds ---
# Additional visits: 8609.919749586432
# Additional visits: 8827.930098687753
# Additional visits: 7635.208653131156
# Additional visits: 8659.925367718828
# Additional visits: 8258.996822709003
# Additional visits: 7925.999569639576
# --- Time to fit (and tune) causal tree 0.03564858436584473 seconds ---
# --- Time to fit (and tune) causal tree 0.08081483840942383 seconds ---
# --- Time to fit (and tune) causal tree 6.849995136260986 seconds ---
# --- Time to fit (and tune) causal tree 0.22747230529785156 seconds ---
# --- Time to fit (and tune) causal tree 2.4825189113616943 seconds ---
# Additional visits: 8096.501194032825
# Additional visits: 8484.79308806795
# --- Time to fit (and tune) causal tree 22.147108793258667 seconds ---
# --- Time to fit (and tune) causal tree 0.8100886344909668 seconds ---
# Additional visits: 8274.515313201142
# Additional visits: 8115.897510903469
# Additional visits: 8103.899837156406
# --- Time to fit (and tune) causal tree 2.358245372772217 seconds ---
# --- Time to fit (and tune) causal tree 0.03715348243713379 seconds ---
# Additional visits: 8587.159830330807
# Additional visits: 8700.3793719194
# --- Time to fit (and tune) causal tree 0.08640432357788086 seconds ---
# Additional visits: 8576.973512123588
# --- Time to fit (and tune) causal tree 0.24318337440490723 seconds ---
# --- Time to fit (and tune) causal tree 7.276183605194092 seconds ---
# --- Time to fit (and tune) causal tree 22.606059551239014 seconds ---
# --- Time to fit (and tune) causal tree 0.8205313682556152 seconds ---
# Additional visits: 8523.7802751618
# Additional visits: 8548.049671107192
# Additional visits: 8664.59055341035
# Additional visits: 8257.097522966622
# --- Time to fit (and tune) causal tree 0.036881208419799805 seconds ---
# --- Time to fit (and tune) causal tree 19.626582622528076 seconds ---
# Additional visits: 8475.102115414576
# --- Time to fit (and tune) causal tree 0.07926225662231445 seconds ---
# --- Time to fit (and tune) causal tree 6.983596563339233 seconds ---
# --- Time to fit (and tune) causal tree 2.2008912563323975 seconds ---
# Additional visits: 8873.179803238236
# Additional visits: 8834.700174871714
# --- Time to fit (and tune) causal tree 17.03350043296814 seconds ---
# Additional visits: 8082.068686623794
# --- Time to fit (and tune) causal tree 0.22954750061035156 seconds ---
# --- Time to fit (and tune) causal tree 0.7439517974853516 seconds ---
# Additional visits: 8348.387225956016
# Additional visits: 8273.408350855418
# --- Time to fit (and tune) causal tree 2.2130327224731445 seconds ---
# Additional visits: 8280.399652181994
# Additional visits: 8627.018254101926
# --- Time to fit (and tune) causal tree 0.03680062294006348 seconds ---
# --- Time to fit (and tune) causal tree 0.08698129653930664 seconds ---
# --- Time to fit (and tune) causal tree 6.816003322601318 seconds ---
# Additional visits: 8459.219992667773
# Additional visits: 8613.892914205346
# --- Time to fit (and tune) causal tree 0.23772525787353516 seconds ---
# Additional visits: 8594.533837626695
# --- Time to fit (and tune) causal tree 0.742326021194458 seconds ---
# Additional visits: 8363.909809510611
# Additional visits: 8658.883573361214
# Additional visits: 8543.503671757433
# Additional visits: 8721.900723014323
# --- Time to fit (and tune) causal tree 6.28481388092041 seconds ---
# Additional visits: 8021.324169981659
# Additional visits: 8709.911557912745
# --- Time to fit (and tune) causal tree 2.3899853229522705 seconds ---
# Additional visits: 8702.208529622281
# --- Time to fit (and tune) causal tree 22.97395348548889 seconds ---
# Additional visits: 8334.822566824325
# Additional visits: 8483.946670655676
# Additional visits: 8458.66468170633
# --- Time to fit (and tune) causal tree 21.502321481704712 seconds ---
# --- Time to fit (and tune) causal tree 7.145408868789673 seconds ---
# Additional visits: 8565.858356865396
# Additional visits: 8742.178005941578
# --- Time to fit (and tune) causal tree 18.5291588306427 seconds ---
# Additional visits: 8543.752404867084
# --- Time to fit (and tune) causal tree 19.039825439453125 seconds ---
# Additional visits: 8789.30059815607
# Additional visits: 8447.542404657783
# Additional visits: 8430.446345080105
# --- Time to fit (and tune) causal tree 18.827356338500977 seconds ---
# Additional visits: 8628.600883754372
# Additional visits: 8393.3300361222
# Done!
# Total time: 8.855 minutes

# %%
curve_results = pd.read_csv(f'../{resdir}/learning_curve_results.csv')
mask = curve_results.seed<50
backup = curve_results[mask].groupby('size').agg(
    performance=('improvement', 'mean'),
    std_dev=('improvement', 'std')
)
backup = pd.DataFrame(backup).reset_index()
backup['size'] = backup['size'].apply(lambda x: size2label[x])

margin = st.norm.ppf(0.975)
backup['upper_bound'] = backup.apply(lambda x: x['performance'] + margin*x['std_dev'], axis=1)
backup['lower_bound'] = backup.apply(lambda x: x['performance'] - margin*x['std_dev'], axis=1)
backup.to_csv(f'../{resdir}/learning_curve.csv', index=False)

# %%
eval_df['pred'] = 1
avg_benefit = get_improvement(eval_df,0.3)

breakevens = []
for size in curve_sizes[4:]:
    invested_size = size - curve_sizes[1]
    inference_size = eval_df.shape[0] - invested_size
    breakeven = 100 * (obs_benefit - avg_benefit) * invested_size / (inference_size * obs_benefit)
    breakevens.append(breakeven)
    print(breakeven)

pd.DataFrame(data={'size': curve_sizes[4:], 'breakeven': breakevens}).to_csv(
    f'../{resdir}/breakeven.csv', index=False
)
# Out:
# Additional visits: 3167.6746795729027
# -0.15442350789336445
# -0.3347550265130936
# -0.7118073782923888

# %%
backup = pd.read_csv(f'../{resdir}/learning_curve.csv')
improvements = backup['performance']
labels = backup['size']
upper_bounds = backup['upper_bound']
lower_bounds = backup['lower_bound']
plt.plot(labels, [0, 0, 0, 0] + breakevens, color='black', linestyle='dashed', label="Break-even improvement")
plt.plot(labels, improvements[:4].tolist() + [None, None, None], color='tab:orange', label="Learning curve, observed")
plt.plot(labels, [None] + improvements[1:].tolist(), color='tab:orange', linestyle='dotted', label="Learning curve, unobserved")
# plt.fill_between(labels, upper_bounds, lower_bounds, color='gray', alpha=0.5)
plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])
plt.ylabel("Improvement of EM over OM")
plt.xlabel("Size of the experimental data")
plt.legend(loc='lower right')
# plt.savefig(f"../{resdir}/learning_curve.png", dpi=200, bbox_inches="tight")
# Out:
# /tmp/ipykernel_95045/2641577411.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])

# %% [markdown]
# # Confidence Intervals

# %%
visits = obs_df.groupby('treatment').visit.mean()
counts = obs_df.groupby('treatment').visit.count()
variances = obs_df.groupby('treatment').visit.var()
print(f"Naive confounded: {(visits[1] - visits[0])*100:.2f}%")
print(f"S.E.: {np.sqrt((variances/counts).sum())*100*1.96:.2f}%")
###################
visits = df.groupby('treatment').visit.mean()
counts = df.groupby('treatment').visit.count()
variances = df.groupby('treatment').visit.var()
print(f"Ground truth: {(visits[1] - visits[0])*100:.2f}%")
print(f"S.E.: {np.sqrt((variances/counts).sum())*100*1.96:.2f}%")

# %% [markdown]
# Bootstrapping the experimental model.

# %%
from sklearn.utils import resample

bootstrap_size = 100
results = []
for i in range(bootstrap_size):
    print(i)
    data = resample(limited_exp, replace=True, random_state=i)
    tree = fit_tree(data, tune=False, min_samples_leaf=limited_tree.min_samples_leaf)
    result = tree.predict(data[limited_features]).mean()
    results.append(result)

# %%
pd.Series(results).hist()
print(f"Unconfounded model: {np.mean(results)*100:.2f}%")
print(f"Unconfounded model (SE): {np.std(results)*100*1.96:.2f}%")

# %%
bootstrap_size = 10
results = []
for i in range(bootstrap_size):
    print(i)
    data = resample(obs_df, replace=True, random_state=i)
    #tree = fit_tree(data, tune=False, min_samples_leaf=obs_tree.min_samples_leaf)
    tree = fit_tree(data, tune=False, min_samples_leaf=32000)
    result = tree.predict(data[limited_features]).mean()
    results.append(result)

# %%
pd.Series(results).hist()

# %%
print(f"Confounded model: {pd.Series(results).mean()*100:.2f}%")
print(f"Confounded model S.E.: {pd.Series(results).std()*100*1.96:.2f}%")
