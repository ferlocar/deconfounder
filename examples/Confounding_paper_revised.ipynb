# %% [markdown]
# # Load and create data sets

# %% [markdown]
# Load data.

# %%
### LINES TO IMPORT THE DECONFOUNDER PACKAGE IN THE PARENT FOLDER ###
import os
import sys
sys.path.append("..")
### IMPORTS
from deconfounder.causal_tree import CausalTree
from deconfounder.causal_forest import CausalForest
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import numpy as np
from numpy.polynomial.polynomial import polyfit
import pandas as pd
import scipy.stats as st
from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict
import time
from sklearn.utils.parallel import Parallel, delayed

# %%
# Load data
df = pd.read_csv("../data/criteo-uplift-v2.1.csv")
df = df.sample(frac=1, random_state=42)
all_features = df.columns.values[:12].tolist()

# %% [markdown]
# Find the feature that is correalted the most with the outcome and remove that feature (i.e., the confounder).

# %%
corr_matrix = df[all_features + ['visit']].corr()
confounder = corr_matrix['visit'][:-1].sort_values().index.values[-1]
print(confounder)
limited_features = list(all_features)
limited_features.remove(confounder)
# Out:
# f9

# %% [markdown]
# Obtain observational data. Drop observations using the confounder.

# %%
def print_outcomes(data):
    means = data.groupby('treatment').visit.mean()
    print(f"Size of data set: {data.shape[0]:,}")
    print(f"Avg. Outcome (treated): {np.round(means.loc[1]*100, 2)}%")
    print(f"Avg. Outcome (control): {np.round(means.loc[0]*100, 2)}%")
    print(f"Estimated avg. effect: {np.round((means.loc[1]-means.loc[0])*100, 2)}%")

train_frac = 0.5
train_size = int(df.shape[0]*train_frac)
obs_df = df[:train_size]
train_df = df[:train_size]
drop_frac = 0.1

conf_ranking = obs_df[confounder].rank(method="first")
keep =  ((obs_df.treatment == 1) & (conf_ranking > int(train_size * drop_frac))) | \
        ((obs_df.treatment == 0) & (conf_ranking < int(train_size * (1 - drop_frac))))
obs_df = train_df[keep]
print("Observational (naive) setup")
print_outcomes(obs_df)
print("-------------")
exp_df = train_df.sample(n=obs_df.shape[0],random_state=42)
print("Experimental setup")
print_outcomes(exp_df)
print("-------------")
print("Entire data")
print_outcomes(df)
# Out:
# Observational (naive) setup
# Size of data set: 6,297,527
# Avg. Outcome (treated): 5.31%
# Avg. Outcome (control): 1.23%
# Estimated avg. effect: 4.08%
# -------------
# Experimental setup
# Size of data set: 6,297,527
# Avg. Outcome (treated): 4.86%
# Avg. Outcome (control): 3.8%
# Estimated avg. effect: 1.06%
# -------------
# Entire data
# Size of data set: 13,979,592
# Avg. Outcome (treated): 4.85%
# Avg. Outcome (control): 3.82%
# Estimated avg. effect: 1.03%

# %% [markdown]
# Build causal tree using observational data. Control for observable confounding.

# %%
def fit_tree(df_causal, tree_type=CausalForest, min_samples_leaf=5000, tune=False, params=None, scoring=None, verbose=True):    
    X = df_causal[limited_features + ['treatment']].rename(columns={"treatment":"treated"})
    y =  df_causal.visit
    # Fit and tune causal tree
    start_time = time.time()
    if tune:
        if params is None:
            params = range(1000, 10000, 1000)
        tuned_parameters = [{'min_samples_leaf': params}]
        grid_tree = GridSearchCV(tree_type(random_state=42, n_estimators=10), tuned_parameters, cv=4, 
                                 verbose=10, n_jobs=4, scoring=scoring)
        grid_tree.fit(X, y)
        print("Best parameters set found on development set:")
        print(grid_tree.best_params_)
        tree_model = grid_tree.best_estimator_
    else:
        ### WARNING: if n_jobs is different from 1, the code breaks
        tree_model = tree_type(min_samples_leaf=min_samples_leaf, random_state=42, n_estimators=10)
        tree_model.fit(X, y)
    if verbose:
        print("--- Time to fit (and tune) causal tree %s seconds ---" % (time.time() - start_time))
    return tree_model

#obs_tree = fit_tree(obs_df, tune=True, params=[8000, 16000, 32000, 64000, 128000])
#Best parameters set found on development set:
#{'min_samples_leaf': 32000}
#--- Time to fit (and tune) causal tree 1082.7572462558746 seconds ---
obs_tree = fit_tree(obs_df, min_samples_leaf=32000)
# Out:
# --- Time to fit (and tune) causal tree 310.08350253105164 seconds ---

# %% [markdown]
# Obtain evaluation data

# %%
eval_df = df[train_size:].copy()

# %% [markdown]
# Estimated average causal effect after accounting for observed confounding.

# %%
print("Observational ('smart') setup")
obs_preds = obs_tree.predict(eval_df[limited_features])
obs_avg_effect = obs_preds.mean()
print(f"Estimated avg. effect: {np.round(obs_avg_effect*100, 2)}%")
# Out:
# Observational ('smart') setup
# Estimated avg. effect: 2.89%

# %% [markdown]
# # Approach 1: Domain Knowledge

# %% [markdown]
# Suppose visit value is \\$ 0.50 and the cost is \\$ 0.01. How does the bias may affect ability to identify profitable customers?

# %%
visit_value = 0.49
ad_cost = 0.01
total_impressions = 1000000
boundary = ad_cost/(visit_value+ad_cost)

def get_avg_benefit(e_df, boundary=None):
    if boundary is None:
        boundary = ad_cost/(visit_value+ad_cost)
    targeted = e_df.pred > boundary 
    avg_outcomes = e_df[targeted].groupby('treatment').visit.mean()
    fraction = targeted.mean()
    additional_visits = (avg_outcomes.loc[1] - avg_outcomes.loc[0]) * fraction 
    benefit = (additional_visits*visit_value - fraction*ad_cost)*total_impressions
    print(f"Benefit ($) per 1 MM users: {round(benefit):,}")
    return benefit

print("Real benefit (compared with sensitivity analysis)")
print("------")
print("Observational")
eval_df['pred'] = obs_preds
obs_benefit = get_avg_benefit(eval_df)
# Out:
# Real benefit (compared with sensitivity analysis)
# ------
# Observational
# Benefit ($) per 1 MM users: 1,753

# %% [markdown]
# Get cross-validation predictions.

# %%
X = obs_df[limited_features + ['treatment']].rename(columns={"treatment":"treated"})
y =  obs_df.visit
cross_preds = cross_val_predict(CausalForest(min_samples_leaf=obs_tree.min_samples_leaf, random_state=42, n_estimators=10), 
                                X, y, cv=5, verbose=10, n_jobs=5)
# Out:
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done   2 out of   5 | elapsed:  2.8min remaining:  4.2min
# [Parallel(n_jobs=5)]: Done   3 out of   5 | elapsed:  2.8min remaining:  1.9min
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:  2.9min remaining:    0.0s
# [Parallel(n_jobs=5)]: Done   5 out of   5 | elapsed:  2.9min finished

# %%
targeted = cross_preds > boundary
biased_avg_effect = obs_preds.mean()
estimated_effects = obs_tree.predict(obs_df[limited_features])

bias_size = 0.87
real_size = (1-bias_size)
additional_visits = ((estimated_effects * real_size) * targeted).mean()
benefit =  round((additional_visits*visit_value - targeted.mean()*ad_cost)*total_impressions)
benefit
# Out:
# -56

# %% [markdown]
# Assess how much could the bias affect the decisions.

# %%
means = eval_df.groupby('treatment').visit.mean()
avg_effect = means.loc[1]-means.loc[0]

real_avg_bias = round(1 - avg_effect/biased_avg_effect, 2)

bias_sizes = np.arange(11)/10
benefits = []
for bias_size in bias_sizes:
    real_size = (1-bias_size)
    additional_visits = ((estimated_effects * real_size) * targeted).mean()
    benefit =  round((additional_visits*visit_value - targeted.mean()*ad_cost)*total_impressions)
    benefits.append(benefit)

figs = plt.plot(bias_sizes*100, benefits, label="Estimation (w. sensitivity analysis)")
plt.xlabel("Bias size (as % of estimated effect)")
plt.ylabel("Profit (per 1MM consumers)")
# Set Y axis
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
figs[0].axes.yaxis.set_major_formatter(tick)
# Set X axis
figs[0].axes.xaxis.set_major_formatter(mtick.PercentFormatter())
# Break-even line
plt.plot([0, 100], [0, 0], linestyle='--', color='black')
plt.plot([real_avg_bias*100], [obs_benefit], marker="*", label="Ground truth")
plt.legend()
# plt.savefig("sensitivity_analysis.png", dpi=200, bbox_inches="tight")

# %% [markdown]
# # Approach 2: What if there is some experimental data?

# %% [markdown]
# What's the best tree we could get with limited experimental data?

# %%
limited_exp = exp_df.sample(50000,random_state=42)
limited_tree = fit_tree(limited_exp, tune=True, params=np.arange(1, 11)*1000)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# [CV 3/4; 1/10] START min_samples_leaf=1000......................................
# [CV 4/4; 1/10] START min_samples_leaf=1000......................................
# [CV 1/4; 1/10] START min_samples_leaf=1000......................................
# [CV 2/4; 1/10] START min_samples_leaf=1000......................................
# [CV 4/4; 1/10] END .......min_samples_leaf=1000;, score=0.001 total time=   0.4s
# [CV 1/4; 1/10] END .......min_samples_leaf=1000;, score=0.000 total time=   0.5s
# [CV 3/4; 1/10] END .......min_samples_leaf=1000;, score=0.000 total time=   0.5s
# [CV 2/4; 1/10] END .......min_samples_leaf=1000;, score=0.001 total time=   0.5s
# [CV 1/4; 2/10] START min_samples_leaf=2000......................................
# [CV 2/4; 2/10] START min_samples_leaf=2000......................................
# [CV 3/4; 2/10] START min_samples_leaf=2000......................................
# [CV 4/4; 2/10] START min_samples_leaf=2000......................................
# [CV 1/4; 2/10] END .......min_samples_leaf=2000;, score=0.000 total time=   0.3s
# [CV 1/4; 3/10] START min_samples_leaf=3000......................................
# [CV 2/4; 2/10] END .......min_samples_leaf=2000;, score=0.001 total time=   0.3s
# [CV 4/4; 2/10] END .......min_samples_leaf=2000;, score=0.001 total time=   0.3s
# [CV 2/4; 3/10] START min_samples_leaf=3000......................................
# [CV 3/4; 3/10] START min_samples_leaf=3000......................................
# [CV 3/4; 2/10] END .......min_samples_leaf=2000;, score=0.000 total time=   0.3s
# [CV 4/4; 3/10] START min_samples_leaf=3000......................................
# [CV 1/4; 3/10] END .......min_samples_leaf=3000;, score=0.000 total time=   0.3s
# [CV 1/4; 4/10] START min_samples_leaf=4000......................................
# [CV 2/4; 3/10] END .......min_samples_leaf=3000;, score=0.001 total time=   0.3s
# [CV 4/4; 3/10] END .......min_samples_leaf=3000;, score=0.001 total time=   0.3s
# [CV 3/4; 3/10] END .......min_samples_leaf=3000;, score=0.000 total time=   0.3s
# [CV 2/4; 4/10] START min_samples_leaf=4000......................................
# [CV 3/4; 4/10] START min_samples_leaf=4000......................................
# [CV 4/4; 4/10] START min_samples_leaf=4000......................................
# [CV 1/4; 4/10] END .......min_samples_leaf=4000;, score=0.000 total time=   0.3s
# [CV 1/4; 5/10] START min_samples_leaf=5000......................................
# [CV 2/4; 4/10] END .......min_samples_leaf=4000;, score=0.001 total time=   0.2s
# [CV 2/4; 5/10] START min_samples_leaf=5000......................................
# [CV 3/4; 4/10] END .......min_samples_leaf=4000;, score=0.000 total time=   0.2s
# [CV 3/4; 5/10] START min_samples_leaf=5000......................................
# [CV 4/4; 4/10] END .......min_samples_leaf=4000;, score=0.000 total time=   0.2s
# [CV 4/4; 5/10] START min_samples_leaf=5000......................................
# [CV 1/4; 5/10] END .......min_samples_leaf=5000;, score=0.000 total time=   0.2s
# [CV 1/4; 6/10] START min_samples_leaf=6000......................................
# [CV 2/4; 5/10] END .......min_samples_leaf=5000;, score=0.001 total time=   0.2s
# [CV 2/4; 6/10] START min_samples_leaf=6000......................................
# [CV 3/4; 5/10] END .......min_samples_leaf=5000;, score=0.000 total time=   0.2s
# [CV 4/4; 5/10] END .......min_samples_leaf=5000;, score=0.001 total time=   0.2s
# [CV 3/4; 6/10] START min_samples_leaf=6000......................................
# [CV 4/4; 6/10] START min_samples_leaf=6000......................................
# [CV 1/4; 6/10] END .......min_samples_leaf=6000;, score=0.000 total time=   0.2s
# [CV 1/4; 7/10] START min_samples_leaf=7000......................................
# [CV 2/4; 6/10] END .......min_samples_leaf=6000;, score=0.001 total time=   0.2s
# [CV 2/4; 7/10] START min_samples_leaf=7000......................................
# [CV 3/4; 6/10] END .......min_samples_leaf=6000;, score=0.000 total time=   0.2s
# [CV 4/4; 6/10] END .......min_samples_leaf=6000;, score=0.000 total time=   0.2s
# [CV 3/4; 7/10] START min_samples_leaf=7000......................................
# [CV 4/4; 7/10] START min_samples_leaf=7000......................................
# [CV 1/4; 7/10] END .......min_samples_leaf=7000;, score=0.000 total time=   0.2s
# [CV 2/4; 7/10] END .......min_samples_leaf=7000;, score=0.001 total time=   0.2s
# [CV 1/4; 8/10] START min_samples_leaf=8000......................................
# [CV 2/4; 8/10] START min_samples_leaf=8000......................................
# [CV 3/4; 7/10] END .......min_samples_leaf=7000;, score=0.000 total time=   0.2s
# [CV 4/4; 7/10] END .......min_samples_leaf=7000;, score=0.000 total time=   0.2s
# [CV 3/4; 8/10] START min_samples_leaf=8000......................................
# [CV 4/4; 8/10] START min_samples_leaf=8000......................................
# [CV 1/4; 8/10] END .......min_samples_leaf=8000;, score=0.000 total time=   0.2s
# [CV 1/4; 9/10] START min_samples_leaf=9000......................................
# [CV 2/4; 8/10] END .......min_samples_leaf=8000;, score=0.000 total time=   0.2s
# [CV 2/4; 9/10] START min_samples_leaf=9000......................................
# [CV 3/4; 8/10] END .......min_samples_leaf=8000;, score=0.000 total time=   0.1s
# [CV 3/4; 9/10] START min_samples_leaf=9000......................................
# [CV 4/4; 8/10] END .......min_samples_leaf=8000;, score=0.000 total time=   0.2s
# [CV 4/4; 9/10] START min_samples_leaf=9000......................................
# [CV 1/4; 9/10] END .......min_samples_leaf=9000;, score=0.000 total time=   0.1s
# [CV 2/4; 9/10] END .......min_samples_leaf=9000;, score=0.000 total time=   0.1s
# [CV 1/4; 10/10] START min_samples_leaf=10000....................................
# [CV 2/4; 10/10] START min_samples_leaf=10000....................................
# [CV 3/4; 9/10] END .......min_samples_leaf=9000;, score=0.000 total time=   0.1s
# [CV 3/4; 10/10] START min_samples_leaf=10000....................................
# [CV 4/4; 9/10] END .......min_samples_leaf=9000;, score=0.000 total time=   0.1s
# [CV 4/4; 10/10] START min_samples_leaf=10000....................................
# [CV 1/4; 10/10] END .....min_samples_leaf=10000;, score=0.000 total time=   0.1s
# [CV 2/4; 10/10] END .....min_samples_leaf=10000;, score=0.000 total time=   0.1s
# [CV 3/4; 10/10] END .....min_samples_leaf=10000;, score=0.000 total time=   0.1s
# [CV 4/4; 10/10] END .....min_samples_leaf=10000;, score=0.000 total time=   0.1s
# Best parameters set found on development set:
# {'min_samples_leaf': 1000}
# --- Time to fit (and tune) causal tree 4.770450115203857 seconds ---

# %% [markdown]
# Compare each other. Experimental does better.

# %%
means = eval_df.groupby('treatment').visit.mean()
avg_effect = means.loc[1]-means.loc[0]
total_impressions = 1000000
size = 100

def plot_random(e_df):
    means = e_df.groupby('treatment').visit.mean()
    avg_effect = means.loc[1]-means.loc[0]
    fractions = (np.arange(size)+1)/size
    plt.plot(fractions*100, fractions*avg_effect*total_impressions, 
             color='black', linestyle='dashed', label="Random targeting")
    plt.legend()

def evaluate(e_df, title):
    e_df = e_df.sort_values('pred', ascending=False)
    cum_per = np.arange(e_df.shape[0]) / e_df.shape[0]
    fractions = []
    effects = []
    for i in range(size):
        targeted = cum_per < (i+1)/size
        fraction = targeted.mean()
        avg_outcomes = e_df[targeted].groupby('treatment').visit.mean()
        additional_visits = (avg_outcomes.loc[1] - avg_outcomes.loc[0]) * fraction * total_impressions
        fractions.append(fraction)
        effects.append(additional_visits)
    figs = plt.plot(np.array(fractions)*100, effects, label=title)
    plt.xlabel("% of users targeted")
    plt.ylabel("Incremental visits (per 1MM consumers)")
    # Set Y axis
    fmt = '{x:,.0f}'
    tick = mtick.StrMethodFormatter(fmt)
    figs[0].axes.yaxis.set_major_formatter(tick)
    # Set X axis
    figs[0].axes.xaxis.set_major_formatter(mtick.PercentFormatter())
    plt.legend()

# %%
X = limited_exp[limited_features + ['treatment']].rename(columns={"treatment":"treated"})
y =  limited_exp.visit
exp_cross_preds = cross_val_predict(CausalForest(min_samples_leaf=limited_tree.min_samples_leaf, random_state=42, 
                                                 n_estimators=10), X, y, cv=10, verbose=10)

copy_exp_df = limited_exp.copy()
size=30
copy_exp_df['pred'] = obs_tree.predict(copy_exp_df[limited_features])
evaluate(copy_exp_df, "Observational model")
copy_exp_df['pred'] = exp_cross_preds
evaluate(copy_exp_df, "Experimental model")
#plt.axhline(y=0, color='black', linestyle='--')
plot_random(copy_exp_df)
plt.xlim(left=0)
plt.savefig("../results/eval_comparison.png", dpi=200, bbox_inches="tight")
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    4.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    5.4s finished

# %% [markdown]
# Average effect estimated by the experimental tree.

# %%
exp_cross_preds.mean() * 100
# Out:
# 1.2585032074228768

# %% [markdown]
# Benefit evaluation

# %%
print("Observational")
copy_exp_df['pred'] = obs_tree.predict(copy_exp_df[limited_features])
obs_benefit = get_avg_benefit(copy_exp_df)
print("Experimental")
copy_exp_df['pred'] = exp_cross_preds
exp_benefit = get_avg_benefit(copy_exp_df)
# Out:
# Observational
# Benefit ($) per 1 MM users: 3,742
# Experimental
# Benefit ($) per 1 MM users: 3,130

# %%
print("Observational")
eval_df['pred'] = obs_preds
obs_benefit = get_avg_benefit(eval_df)
print("Experimental")
eval_df['pred'] = limited_tree.predict(eval_df[limited_features])
exp_benefit = get_avg_benefit(eval_df)
# Out:
# Observational
# Benefit ($) per 1 MM users: 1,753
# Experimental
# Benefit ($) per 1 MM users: 1,598

# %% [markdown]
# # Approach 3: What if we can invest in data?

# %%
def get_improvement(e_df, top=0.3):
    #targeted = e_df.pred >= np.percentile(e_df.pred, 100-top)
    targeted = eval_df.pred.argsort().tail(int(eval_df.shape[0] * top))
    avg_outcomes = e_df.iloc[targeted].groupby('treatment').visit.mean()
    additional_visits = (avg_outcomes.loc[1] - avg_outcomes.loc[0]) * top * total_impressions
    print(f"Additional visits: {additional_visits}")
    return additional_visits

# %%
start_time = time.time()
eval_df['pred'] = obs_tree.predict(eval_df[limited_features])
obs_benefit = get_improvement(eval_df)

def run_single_experimental_model(exp_size, seed):

    # print(f"Experimental data size: {exp_size}")
    subset_exp = exp_df.sample(exp_size,random_state=seed)
    subset_tree = fit_tree(subset_exp, tune=False, min_samples_leaf=limited_tree.min_samples_leaf)
    eval_df['pred'] = subset_tree.predict(eval_df[limited_features])
    exp_benefit = get_improvement(eval_df)
    improvement = 100 * (exp_benefit/obs_benefit - 1)
    # print(f"Improvement: {improvement}")
    result = {'seed': seed, 'size': exp_size, 'improvement': improvement}
    return result

curve_sizes = np.array([6000, 12000, 25000, 50000, 100000, 200000, 400000])
labels = ['6k', '12k', '25k', '50k', '100k', '200k', '400k']
size2label = dict((curve_sizes[i], labels[i]) for i in range(len(labels)))

parallel = Parallel(n_jobs=12)
func = delayed(run_single_experimental_model)

curve_results = parallel(func(
    exp_size=exp_size,
    seed=seed
    )
    for seed in range(0, 100)
        for exp_size in curve_sizes
)

curve_results = pd.DataFrame(curve_results)
curve_results.to_csv('../results/learning_curve_results.csv', index=False)

print('Done!')
print(f'Total time: {(time.time()-start_time)/60:.3f} minutes')
# Out:
# Additional visits: 8639.706817380149
# --- Time to fit (and tune) causal tree 0.03206634521484375 seconds ---
# --- Time to fit (and tune) causal tree 0.0326075553894043 seconds ---
# --- Time to fit (and tune) causal tree 0.07709479331970215 seconds ---
# --- Time to fit (and tune) causal tree 0.07129406929016113 seconds ---
# --- Time to fit (and tune) causal tree 0.2287123203277588 seconds ---
# --- Time to fit (and tune) causal tree 0.22858905792236328 seconds ---
# --- Time to fit (and tune) causal tree 0.7783908843994141 seconds ---
# --- Time to fit (and tune) causal tree 0.7764987945556641 seconds ---
# --- Time to fit (and tune) causal tree 2.0821712017059326 seconds ---
# --- Time to fit (and tune) causal tree 2.4659769535064697 seconds ---
# Additional visits: 8542.048549523299
# Additional visits: 8639.706187649597
# Additional visits: 8608.623581136631
# Additional visits: 8783.768777613763
# --- Time to fit (and tune) causal tree 0.034046173095703125 seconds ---
# --- Time to fit (and tune) causal tree 0.08302783966064453 seconds ---
# Additional visits: 8821.794793617566
# Additional visits: 8266.426265900638
# --- Time to fit (and tune) causal tree 0.23162150382995605 seconds ---
# --- Time to fit (and tune) causal tree 0.7132518291473389 seconds ---
# Additional visits: 8498.414235929511
# Additional visits: 8353.942385754006
# --- Time to fit (and tune) causal tree 7.13277006149292 seconds ---
# Additional visits: 8313.901484459298
# Additional visits: 8675.558270175756
# --- Time to fit (and tune) causal tree 0.0342557430267334 seconds ---
# Additional visits: 8519.414082646339
# --- Time to fit (and tune) causal tree 2.253985643386841 seconds ---
# Additional visits: 8379.211727254793
# --- Time to fit (and tune) causal tree 0.08008337020874023 seconds ---
# --- Time to fit (and tune) causal tree 6.163085222244263 seconds ---
# --- Time to fit (and tune) causal tree 0.22419381141662598 seconds ---
# Additional visits: 7740.687858146397
# --- Time to fit (and tune) causal tree 0.7128431797027588 seconds ---
# Additional visits: 8322.844395978926
# Additional visits: 7471.6973706826875
# Additional visits: 8667.139323740128
# --- Time to fit (and tune) causal tree 6.700199365615845 seconds ---
# --- Time to fit (and tune) causal tree 2.079413414001465 seconds ---
# Additional visits: 8588.209495303532
# Additional visits: 8568.243581458442
# --- Time to fit (and tune) causal tree 0.03459286689758301 seconds ---
# --- Time to fit (and tune) causal tree 0.07927656173706055 seconds ---
# Additional visits: 8732.36661862547
# --- Time to fit (and tune) causal tree 0.21413254737854004 seconds ---
# Additional visits: 8655.549201691383
# Additional visits: 8418.074792608868
# Additional visits: 8460.120778032064
# --- Time to fit (and tune) causal tree 0.7689242362976074 seconds ---
# Additional visits: 7958.662603641623
# --- Time to fit (and tune) causal tree 6.933668613433838 seconds ---
# --- Time to fit (and tune) causal tree 16.758118391036987 seconds ---
# --- Time to fit (and tune) causal tree 2.284170627593994 seconds ---
# --- Time to fit (and tune) causal tree 21.081963539123535 seconds ---
# Additional visits: 8692.608184132681
# Additional visits: 8672.721094580538
# Additional visits: 8214.229201130025
# --- Time to fit (and tune) causal tree 0.033730506896972656 seconds ---
# --- Time to fit (and tune) causal tree 0.07831239700317383 seconds ---
# --- Time to fit (and tune) causal tree 0.2243342399597168 seconds ---
# Additional visits: 8172.948468261925
# Additional visits: 8673.357323477774
# --- Time to fit (and tune) causal tree 0.685476541519165 seconds ---
# Additional visits: 8533.027965891886
# --- Time to fit (and tune) causal tree 7.1199424266815186 seconds ---
# Additional visits: 8598.037405254949
# Additional visits: 8499.321387619357
# Additional visits: 8676.465798282736
# --- Time to fit (and tune) causal tree 2.037243604660034 seconds ---
# --- Time to fit (and tune) causal tree 19.9894597530365 seconds ---
# --- Time to fit (and tune) causal tree 0.03440093994140625 seconds ---
# --- Time to fit (and tune) causal tree 0.07818365097045898 seconds ---
# Additional visits: 8577.857908257301
# Additional visits: 8580.184303770327
# --- Time to fit (and tune) causal tree 0.25704169273376465 seconds ---
# Additional visits: 9037.41623118285
# Additional visits: 8550.115402383299
# --- Time to fit (and tune) causal tree 0.7579028606414795 seconds ---
# --- Time to fit (and tune) causal tree 17.688371658325195 seconds ---
# Additional visits: 8675.0016840883
# --- Time to fit (and tune) causal tree 5.848681688308716 seconds ---
# Additional visits: 8487.230695663742
# --- Time to fit (and tune) causal tree 2.441964626312256 seconds ---
# Additional visits: 8389.54723466154
# --- Time to fit (and tune) causal tree 0.03525376319885254 seconds ---
# --- Time to fit (and tune) causal tree 0.08025932312011719 seconds ---
# Additional visits: 8001.292923203401
# --- Time to fit (and tune) causal tree 0.2137148380279541 seconds ---
# Additional visits: 8861.824620735539
# Additional visits: 7888.8627911355825
# Additional visits: 8622.113592307689
# --- Time to fit (and tune) causal tree 0.721977710723877 seconds ---
# --- Time to fit (and tune) causal tree 6.855749130249023 seconds ---
# Additional visits: 8344.139615817567
# --- Time to fit (and tune) causal tree 20.041305780410767 seconds ---
# Additional visits: 8740.03764639625
# --- Time to fit (and tune) causal tree 2.2408483028411865 seconds ---
# --- Time to fit (and tune) causal tree 0.03621530532836914 seconds ---
# Additional visits: 8530.961852050184
# Additional visits: 8560.243544329654
# --- Time to fit (and tune) causal tree 0.07823824882507324 seconds ---
# Additional visits: 7980.139182514641
# --- Time to fit (and tune) causal tree 0.22384929656982422 seconds ---
# --- Time to fit (and tune) causal tree 0.7128286361694336 seconds ---
# Additional visits: 4277.625043368788
# Additional visits: 8350.457163350313
# Additional visits: 1872.9287236817456
# --- Time to fit (and tune) causal tree 6.952408790588379 seconds ---
# --- Time to fit (and tune) causal tree 2.199889898300171 seconds ---
# --- Time to fit (and tune) causal tree 18.764193296432495 seconds ---
# Additional visits: 8681.970230727435
# Additional visits: 8571.289989074927
# Additional visits: 8040.622183875383
# --- Time to fit (and tune) causal tree 0.03599977493286133 seconds ---
# --- Time to fit (and tune) causal tree 0.08079957962036133 seconds ---
# --- Time to fit (and tune) causal tree 0.22771239280700684 seconds ---
# Additional visits: 8786.147258983703
# Additional visits: 8762.481737378685
# --- Time to fit (and tune) causal tree 0.6103429794311523 seconds ---
# Additional visits: 8408.969987814122
# Additional visits: 8932.75114425987
# --- Time to fit (and tune) causal tree 6.883749008178711 seconds ---
# --- Time to fit (and tune) causal tree 2.2791311740875244 seconds ---
# Additional visits: 8948.09757993136
# Additional visits: 8933.012644823075
# --- Time to fit (and tune) causal tree 0.03463244438171387 seconds ---
# Additional visits: 8831.420446302207
# --- Time to fit (and tune) causal tree 0.0803835391998291 seconds ---
# --- Time to fit (and tune) causal tree 0.2290794849395752 seconds ---
# --- Time to fit (and tune) causal tree 22.128878116607666 seconds ---
# Additional visits: 9177.052568887224
# Additional visits: 8828.40841472879
# --- Time to fit (and tune) causal tree 0.7397549152374268 seconds ---
# Additional visits: 7684.299674628141
# --- Time to fit (and tune) causal tree 6.67341685295105 seconds ---
# Additional visits: 7869.642647556217
# --- Time to fit (and tune) causal tree 2.372732639312744 seconds ---
# Additional visits: 9085.89317810555
# Additional visits: 8442.04940587999
# --- Time to fit (and tune) causal tree 0.03339338302612305 seconds ---
# Additional visits: 8377.328036287943
# --- Time to fit (and tune) causal tree 0.07817339897155762 seconds ---
# --- Time to fit (and tune) causal tree 20.86426019668579 seconds ---
# --- Time to fit (and tune) causal tree 0.2377779483795166 seconds ---
# Additional visits: 8235.152183244763
# Additional visits: 7208.896045054564
# --- Time to fit (and tune) causal tree 0.7065958976745605 seconds ---
# --- Time to fit (and tune) causal tree 6.785646915435791 seconds ---
# Additional visits: 7941.836459328886
# Additional visits: 8567.449673489558
# --- Time to fit (and tune) causal tree 19.15557289123535 seconds ---
# Additional visits: 8642.35099750632
# Additional visits: 8238.369029973277
# Additional visits: 8588.257502364626
# --- Time to fit (and tune) causal tree 0.03351426124572754 seconds ---
# --- Time to fit (and tune) causal tree 2.2960450649261475 seconds ---
# --- Time to fit (and tune) causal tree 0.07838177680969238 seconds ---
# --- Time to fit (and tune) causal tree 0.23109841346740723 seconds ---
# Additional visits: 8648.36616396346
# Additional visits: 8571.972890145247
# Additional visits: 8630.43580730503
# --- Time to fit (and tune) causal tree 0.7158615589141846 seconds ---
# Additional visits: 8748.701945189408
# --- Time to fit (and tune) causal tree 18.36505627632141 seconds ---
# --- Time to fit (and tune) causal tree 6.429321050643921 seconds ---
# Additional visits: 8792.616688734302
# Additional visits: 8324.814027067836
# --- Time to fit (and tune) causal tree 0.03374671936035156 seconds ---
# --- Time to fit (and tune) causal tree 0.08278679847717285 seconds ---
# --- Time to fit (and tune) causal tree 2.3102657794952393 seconds ---
# Additional visits: 8832.926150779223
# --- Time to fit (and tune) causal tree 0.23009586334228516 seconds ---
# Additional visits: 8586.111013325979
# Additional visits: 8647.17941682432
# --- Time to fit (and tune) causal tree 0.7061550617218018 seconds ---
# Additional visits: 9000.844566826816
# --- Time to fit (and tune) causal tree 18.018770456314087 seconds ---
# Additional visits: 7772.385137501984
# --- Time to fit (and tune) causal tree 7.030320882797241 seconds ---
# --- Time to fit (and tune) causal tree 2.2042195796966553 seconds ---
# Additional visits: 8452.017278784788
# --- Time to fit (and tune) causal tree 0.034735918045043945 seconds ---
# Additional visits: 8878.265928942163
# Additional visits: 8941.096652319653
# --- Time to fit (and tune) causal tree 0.07931137084960938 seconds ---
# Additional visits: 8732.491345183531
# --- Time to fit (and tune) causal tree 0.215623140335083 seconds ---
# --- Time to fit (and tune) causal tree 0.6582851409912109 seconds ---
# Additional visits: 8445.163954555801
# Additional visits: 5503.823586019495
# --- Time to fit (and tune) causal tree 18.06228804588318 seconds ---
# --- Time to fit (and tune) causal tree 6.930126905441284 seconds ---
# Additional visits: 8448.874382335189
# --- Time to fit (and tune) causal tree 2.0750935077667236 seconds ---
# Additional visits: 8546.156535916403
# Additional visits: 9084.58700081707
# --- Time to fit (and tune) causal tree 0.033269643783569336 seconds ---
# --- Time to fit (and tune) causal tree 0.07756757736206055 seconds ---
# Additional visits: 8587.294576674216
# Additional visits: 8905.489979702492
# --- Time to fit (and tune) causal tree 0.2164473533630371 seconds ---
# Additional visits: 8545.220717177708
# --- Time to fit (and tune) causal tree 0.6600725650787354 seconds ---
# Additional visits: 4716.959376623042
# --- Time to fit (and tune) causal tree 2.1123557090759277 seconds ---
# --- Time to fit (and tune) causal tree 18.71429181098938 seconds ---
# Additional visits: 8434.983313494406
# --- Time to fit (and tune) causal tree 7.076782941818237 seconds ---
# Additional visits: 8469.530068494478
# --- Time to fit (and tune) causal tree 0.03527355194091797 seconds ---
# Additional visits: 8413.783494185056
# Additional visits: 8847.073157599261
# Additional visits: 8757.120905472057
# --- Time to fit (and tune) causal tree 0.07543110847473145 seconds ---
# --- Time to fit (and tune) causal tree 0.2344198226928711 seconds ---
# Additional visits: 8685.954005812782
# --- Time to fit (and tune) causal tree 0.7103650569915771 seconds ---
# Additional visits: 402.0163686088249
# --- Time to fit (and tune) causal tree 2.267538547515869 seconds ---
# Additional visits: 7994.408781333667
# Additional visits: 8516.079331277007
# --- Time to fit (and tune) causal tree 6.772286653518677 seconds ---
# --- Time to fit (and tune) causal tree 0.04631495475769043 seconds ---
# Additional visits: 8022.85806174381
# --- Time to fit (and tune) causal tree 0.07811236381530762 seconds ---
# Additional visits: 8749.391938813795
# --- Time to fit (and tune) causal tree 21.00046730041504 seconds ---
# --- Time to fit (and tune) causal tree 0.2225654125213623 seconds ---
# Additional visits: 9042.329175377085
# Additional visits: 8279.169651733475
# Additional visits: 6390.891610834772
# --- Time to fit (and tune) causal tree 0.7183139324188232 seconds ---
# --- Time to fit (and tune) causal tree 2.296144485473633 seconds ---
# Additional visits: 8392.43076316249
# Additional visits: 8530.74282587251
# --- Time to fit (and tune) causal tree 7.381364345550537 seconds ---
# --- Time to fit (and tune) causal tree 18.435216903686523 seconds ---
# --- Time to fit (and tune) causal tree 0.034705400466918945 seconds ---
# Additional visits: 8286.59608245617
# Additional visits: 8440.826290640749
# --- Time to fit (and tune) causal tree 0.07810330390930176 seconds ---
# --- Time to fit (and tune) causal tree 0.21641039848327637 seconds ---
# Additional visits: 8375.449772597329
# Additional visits: 8674.099041837235
# --- Time to fit (and tune) causal tree 16.01442313194275 seconds ---
# --- Time to fit (and tune) causal tree 0.6739413738250732 seconds ---
# --- Time to fit (and tune) causal tree 7.47822380065918 seconds ---
# Additional visits: 8703.57456632403
# Additional visits: 8657.357819033907
# Additional visits: 8409.831494187598
# --- Time to fit (and tune) causal tree 2.011425256729126 seconds ---
# --- Time to fit (and tune) causal tree 0.03427839279174805 seconds ---
# Additional visits: 8542.961239184446
# --- Time to fit (and tune) causal tree 0.08022260665893555 seconds ---
# Additional visits: 8450.14587831736
# --- Time to fit (and tune) causal tree 0.23105669021606445 seconds ---
# Additional visits: 8810.587200634103
# Additional visits: 7812.303219061045
# Additional visits: 8541.967079891294
# --- Time to fit (and tune) causal tree 0.6513752937316895 seconds ---
# Additional visits: 8551.459560281313
# Additional visits: 8723.94897427937
# Additional visits: 8957.843382116775
# --- Time to fit (and tune) causal tree 2.3002171516418457 seconds ---
# --- Time to fit (and tune) causal tree 0.0351719856262207 seconds ---
# --- Time to fit (and tune) causal tree 6.7067131996154785 seconds ---
# --- Time to fit (and tune) causal tree 0.08131623268127441 seconds ---
# Additional visits: 8654.835511163965
# Additional visits: 8350.800585834751
# --- Time to fit (and tune) causal tree 0.22634410858154297 seconds ---
# --- Time to fit (and tune) causal tree 0.7311863899230957 seconds ---
# --- Time to fit (and tune) causal tree 21.292373180389404 seconds ---
# Additional visits: 8899.452423220038
# Additional visits: 8491.16607693144
# Additional visits: 8445.141147051965
# --- Time to fit (and tune) causal tree 17.86419916152954 seconds ---
# --- Time to fit (and tune) causal tree 7.326306343078613 seconds ---
# --- Time to fit (and tune) causal tree 2.172903060913086 seconds ---
# Additional visits: 7982.629628745733
# Additional visits: 8528.099238242794
# --- Time to fit (and tune) causal tree 0.03780961036682129 seconds ---
# --- Time to fit (and tune) causal tree 0.0782160758972168 seconds ---
# Additional visits: 8193.332656560486
# Additional visits: 8518.38868310388
# --- Time to fit (and tune) causal tree 0.22673964500427246 seconds ---
# --- Time to fit (and tune) causal tree 0.8058700561523438 seconds ---
# Additional visits: 2800.40682722043
# --- Time to fit (and tune) causal tree 6.5052571296691895 seconds ---
# --- Time to fit (and tune) causal tree 17.969921588897705 seconds ---
# Additional visits: 8180.431154422388
# Additional visits: 8478.293484051863
# Additional visits: 8431.791147531585
# --- Time to fit (and tune) causal tree 2.272038221359253 seconds ---
# --- Time to fit (and tune) causal tree 0.035390615463256836 seconds ---
# Additional visits: 8650.77765307304
# Additional visits: 8431.998992943629
# Additional visits: 8703.520425002374
# --- Time to fit (and tune) causal tree 0.07738375663757324 seconds ---
# --- Time to fit (and tune) causal tree 0.23619747161865234 seconds ---
# --- Time to fit (and tune) causal tree 0.7320225238800049 seconds ---
# Additional visits: 8246.536409043165
# Additional visits: 5351.577779732668
# Additional visits: 8305.768906949957
# Additional visits: 8137.457857738487
# --- Time to fit (and tune) causal tree 2.3214359283447266 seconds ---
# --- Time to fit (and tune) causal tree 0.0355379581451416 seconds ---
# --- Time to fit (and tune) causal tree 19.8694748878479 seconds ---
# --- Time to fit (and tune) causal tree 7.193538427352905 seconds ---
# Additional visits: 7381.732616926283
# Additional visits: 8400.488259069678
# --- Time to fit (and tune) causal tree 0.08067607879638672 seconds ---
# Additional visits: 8735.523596732162
# --- Time to fit (and tune) causal tree 0.20415353775024414 seconds ---
# Additional visits: 8087.31281577419
# --- Time to fit (and tune) causal tree 0.6828479766845703 seconds ---
# Additional visits: 8794.61219550091
# --- Time to fit (and tune) causal tree 6.398305892944336 seconds ---
# --- Time to fit (and tune) causal tree 2.389482021331787 seconds ---
# Additional visits: 7850.881963502999
# --- Time to fit (and tune) causal tree 20.2550847530365 seconds ---
# Additional visits: 8553.917614183229
# Additional visits: 7429.0791174538535
# --- Time to fit (and tune) causal tree 0.0348668098449707 seconds ---
# --- Time to fit (and tune) causal tree 0.07921648025512695 seconds ---
# Additional visits: 7745.127205468055
# Additional visits: 8646.152988086049
# --- Time to fit (and tune) causal tree 0.22865891456604004 seconds ---
# Additional visits: 8440.327268273288
# --- Time to fit (and tune) causal tree 0.730720043182373 seconds ---
# Additional visits: 5828.355273942555
# Additional visits: 8346.170103483031
# --- Time to fit (and tune) causal tree 8.00137972831726 seconds ---
# Additional visits: 8146.505363851428
# Additional visits: 8810.85650645841
# --- Time to fit (and tune) causal tree 2.2564830780029297 seconds ---
# --- Time to fit (and tune) causal tree 0.03841757774353027 seconds ---
# --- Time to fit (and tune) causal tree 0.07892084121704102 seconds ---
# Additional visits: 8275.96578336558
# --- Time to fit (and tune) causal tree 0.22136378288269043 seconds ---
# --- Time to fit (and tune) causal tree 21.715125560760498 seconds ---
# Additional visits: 8124.830339850472
# Additional visits: 8659.596026771376
# Additional visits: 6402.2300444078965
# --- Time to fit (and tune) causal tree 17.32046151161194 seconds ---
# --- Time to fit (and tune) causal tree 0.7797245979309082 seconds ---
# Additional visits: 7866.728096689178
# --- Time to fit (and tune) causal tree 7.614896774291992 seconds ---
# --- Time to fit (and tune) causal tree 2.615875720977783 seconds ---
# Additional visits: 8716.263381322118
# Additional visits: 8490.940233052068
# --- Time to fit (and tune) causal tree 0.03247356414794922 seconds ---
# Additional visits: 8505.180357936348
# --- Time to fit (and tune) causal tree 0.07780027389526367 seconds ---
# --- Time to fit (and tune) causal tree 0.21831917762756348 seconds ---
# Additional visits: 7743.836949627656
# Additional visits: 7982.780320132172
# --- Time to fit (and tune) causal tree 7.72710394859314 seconds ---
# --- Time to fit (and tune) causal tree 0.704134464263916 seconds ---
# Additional visits: 8464.708795853412
# Additional visits: 8502.724413266766
# --- Time to fit (and tune) causal tree 2.067903757095337 seconds ---
# Additional visits: 8734.902820411024
# Additional visits: 8309.244682037199
# Additional visits: 8455.76021566895
# --- Time to fit (and tune) causal tree 0.034917354583740234 seconds ---
# --- Time to fit (and tune) causal tree 0.07519793510437012 seconds ---
# Additional visits: 8584.33419602903
# --- Time to fit (and tune) causal tree 0.21429014205932617 seconds ---
# --- Time to fit (and tune) causal tree 21.743034601211548 seconds ---
# --- Time to fit (and tune) causal tree 0.79770827293396 seconds ---
# Additional visits: 8568.109441221448
# Additional visits: 8997.760573821708
# Additional visits: 8665.35375832392
# Additional visits: 8556.618426670124
# --- Time to fit (and tune) causal tree 20.81102752685547 seconds ---
# --- Time to fit (and tune) causal tree 0.03352022171020508 seconds ---
# --- Time to fit (and tune) causal tree 2.2106239795684814 seconds ---
# Additional visits: 8532.930451467362
# --- Time to fit (and tune) causal tree 7.623046636581421 seconds ---
# Additional visits: 8518.795618903645
# --- Time to fit (and tune) causal tree 0.07983708381652832 seconds ---
# --- Time to fit (and tune) causal tree 0.23863482475280762 seconds ---
# Additional visits: 8195.846103003587
# --- Time to fit (and tune) causal tree 0.6956558227539062 seconds ---
# Additional visits: 8627.903182118169
# Additional visits: 8564.591897923181
# Additional visits: 8555.985941740986
# --- Time to fit (and tune) causal tree 6.9071571826934814 seconds ---
# Additional visits: 8357.00170467716
# --- Time to fit (and tune) causal tree 2.2570865154266357 seconds ---
# --- Time to fit (and tune) causal tree 21.055861711502075 seconds ---
# --- Time to fit (and tune) causal tree 0.03596091270446777 seconds ---
# Additional visits: 8194.895873339761
# --- Time to fit (and tune) causal tree 0.07460737228393555 seconds ---
# Additional visits: 8350.518159501802
# Additional visits: 8573.769749302177
# --- Time to fit (and tune) causal tree 0.22219610214233398 seconds ---
# Additional visits: 8402.44831231358
# Additional visits: 4023.007411489596
# --- Time to fit (and tune) causal tree 0.7976312637329102 seconds ---
# Additional visits: 6553.531378531766
# --- Time to fit (and tune) causal tree 18.79707956314087 seconds ---
# --- Time to fit (and tune) causal tree 7.480902194976807 seconds ---
# --- Time to fit (and tune) causal tree 2.527071952819824 seconds ---
# Additional visits: 8891.277851081619
# Additional visits: 8521.981589381769
# --- Time to fit (and tune) causal tree 0.03394174575805664 seconds ---
# --- Time to fit (and tune) causal tree 0.08308005332946777 seconds ---
# Additional visits: 8070.2052093580005
# --- Time to fit (and tune) causal tree 0.23080849647521973 seconds ---
# Additional visits: 8676.57338111515
# Additional visits: 8553.09537166978
# Additional visits: 8625.10628932424
# --- Time to fit (and tune) causal tree 0.7603697776794434 seconds ---
# --- Time to fit (and tune) causal tree 18.52680540084839 seconds ---
# --- Time to fit (and tune) causal tree 7.567547559738159 seconds ---
# Additional visits: 8919.81079736606
# --- Time to fit (and tune) causal tree 2.2978320121765137 seconds ---
# Additional visits: 8041.450162941839
# Additional visits: 8581.415738144222
# --- Time to fit (and tune) causal tree 0.03446364402770996 seconds ---
# --- Time to fit (and tune) causal tree 0.0769343376159668 seconds ---
# Additional visits: 8552.887006425555
# Additional visits: 8862.522024992035
# --- Time to fit (and tune) causal tree 0.22235369682312012 seconds ---
# --- Time to fit (and tune) causal tree 0.7319087982177734 seconds ---
# Additional visits: 9000.442127377815
# --- Time to fit (and tune) causal tree 5.862610340118408 seconds ---
# Additional visits: 8637.159506885937
# Additional visits: 6796.5440220409355
# --- Time to fit (and tune) causal tree 19.7002592086792 seconds ---
# --- Time to fit (and tune) causal tree 2.471752643585205 seconds ---
# Additional visits: 8502.403934417269
# Additional visits: 8630.582374326403
# Additional visits: 8516.414398559997
# Additional visits: 8358.45320472746
# --- Time to fit (and tune) causal tree 0.03451204299926758 seconds ---
# --- Time to fit (and tune) causal tree 0.07805037498474121 seconds ---
# --- Time to fit (and tune) causal tree 0.23071074485778809 seconds ---
# --- Time to fit (and tune) causal tree 0.7381815910339355 seconds ---
# Additional visits: 8183.511853377226
# Additional visits: 7412.861190744717
# --- Time to fit (and tune) causal tree 2.038821220397949 seconds ---
# --- Time to fit (and tune) causal tree 6.526326656341553 seconds ---
# --- Time to fit (and tune) causal tree 18.61886692047119 seconds ---
# Additional visits: 8772.876773948074
# Additional visits: 8690.410867342278
# --- Time to fit (and tune) causal tree 0.03389477729797363 seconds ---
# Additional visits: 8598.476215053288
# --- Time to fit (and tune) causal tree 0.07999992370605469 seconds ---
# Additional visits: 8639.262810605727
# Additional visits: 8055.851459583985
# --- Time to fit (and tune) causal tree 0.22610116004943848 seconds ---
# Additional visits: 8796.604967966334
# Additional visits: 8606.039325483534
# --- Time to fit (and tune) causal tree 0.805044412612915 seconds ---
# --- Time to fit (and tune) causal tree 17.123538732528687 seconds ---
# Additional visits: 8116.115089926922
# --- Time to fit (and tune) causal tree 6.474047899246216 seconds ---
# Additional visits: 8849.520695727773
# --- Time to fit (and tune) causal tree 2.314220905303955 seconds ---
# --- Time to fit (and tune) causal tree 0.03565502166748047 seconds ---
# Additional visits: 8615.467655958382
# Additional visits: 8411.99335283617
# --- Time to fit (and tune) causal tree 0.07781338691711426 seconds ---
# --- Time to fit (and tune) causal tree 0.218003511428833 seconds ---
# Additional visits: 8710.3201781756
# Additional visits: 8449.453997710887
# --- Time to fit (and tune) causal tree 0.7241220474243164 seconds ---
# Additional visits: 8329.632153636137
# --- Time to fit (and tune) causal tree 17.34758186340332 seconds ---
# --- Time to fit (and tune) causal tree 7.263798475265503 seconds ---
# Additional visits: 8454.128840942107
# --- Time to fit (and tune) causal tree 2.336622714996338 seconds ---
# Additional visits: 8519.420621605967
# --- Time to fit (and tune) causal tree 0.035138845443725586 seconds ---
# Additional visits: 8719.590997144027
# Additional visits: 8430.601277861233
# Additional visits: 8881.513760905049
# --- Time to fit (and tune) causal tree 0.08037757873535156 seconds ---
# --- Time to fit (and tune) causal tree 0.234710693359375 seconds ---
# --- Time to fit (and tune) causal tree 0.6951279640197754 seconds ---
# Additional visits: 8281.235534248674
# Additional visits: 8831.16557674623
# --- Time to fit (and tune) causal tree 7.5259833335876465 seconds ---
# Additional visits: 8427.801024966036
# --- Time to fit (and tune) causal tree 18.48353886604309 seconds ---
# --- Time to fit (and tune) causal tree 2.3571507930755615 seconds ---
# Additional visits: 8300.132727798382
# Additional visits: 8296.227762305138
# Additional visits: 8715.89774609332
# --- Time to fit (and tune) causal tree 0.03448772430419922 seconds ---
# --- Time to fit (and tune) causal tree 0.0820164680480957 seconds ---
# Additional visits: 8546.06074709926
# --- Time to fit (and tune) causal tree 0.22037005424499512 seconds ---
# Additional visits: 8642.525308439845
# --- Time to fit (and tune) causal tree 0.6548943519592285 seconds ---
# Additional visits: 2248.4061199749717
# --- Time to fit (and tune) causal tree 2.127878189086914 seconds ---
# --- Time to fit (and tune) causal tree 6.914364576339722 seconds ---
# Additional visits: 8301.092558948669
# Additional visits: 8717.656084836945
# Additional visits: 8568.71212826678
# --- Time to fit (and tune) causal tree 0.034473419189453125 seconds ---
# --- Time to fit (and tune) causal tree 0.07527446746826172 seconds ---
# --- Time to fit (and tune) causal tree 20.071528673171997 seconds ---
# Additional visits: 8841.505534603011
# --- Time to fit (and tune) causal tree 0.2080216407775879 seconds ---
# Additional visits: 8823.869171513275
# Additional visits: 8679.709385314014
# --- Time to fit (and tune) causal tree 0.6891798973083496 seconds ---
# Additional visits: 8657.551572936776
# Additional visits: 8412.28246232328
# Additional visits: 7742.949446042305
# --- Time to fit (and tune) causal tree 2.3470330238342285 seconds ---
# --- Time to fit (and tune) causal tree 0.0348820686340332 seconds ---
# --- Time to fit (and tune) causal tree 7.7141172885894775 seconds ---
# --- Time to fit (and tune) causal tree 19.356210947036743 seconds ---
# Additional visits: 8436.56811063786
# Additional visits: 8399.90324089751
# --- Time to fit (and tune) causal tree 0.07683658599853516 seconds ---
# --- Time to fit (and tune) causal tree 0.22883844375610352 seconds ---
# Additional visits: 8581.960074311979
# Additional visits: 8076.290438692454
# --- Time to fit (and tune) causal tree 0.7129936218261719 seconds ---
# Additional visits: 8860.685942762222
# --- Time to fit (and tune) causal tree 17.58942484855652 seconds ---
# --- Time to fit (and tune) causal tree 6.626224517822266 seconds ---
# Additional visits: 6708.9155752559
# --- Time to fit (and tune) causal tree 2.2588918209075928 seconds ---
# Additional visits: 8403.005687896693
# --- Time to fit (and tune) causal tree 0.034389495849609375 seconds ---
# Additional visits: 7673.915865069925
# --- Time to fit (and tune) causal tree 0.1011362075805664 seconds ---
# Additional visits: 8516.897427587639
# --- Time to fit (and tune) causal tree 0.23220133781433105 seconds ---
# Additional visits: 8676.805193662716
# Additional visits: 3848.2798252323396
# Additional visits: 8377.95089922142
# --- Time to fit (and tune) causal tree 0.642446756362915 seconds ---
# Additional visits: 6744.782949120853
# --- Time to fit (and tune) causal tree 7.616830110549927 seconds ---
# Additional visits: 8517.934048004205
# --- Time to fit (and tune) causal tree 2.339901924133301 seconds ---
# Additional visits: 8792.27644214865
# --- Time to fit (and tune) causal tree 19.420995473861694 seconds ---
# --- Time to fit (and tune) causal tree 0.03610491752624512 seconds ---
# --- Time to fit (and tune) causal tree 0.07977962493896484 seconds ---
# Additional visits: 8578.502200084258
# Additional visits: 8389.154013861973
# --- Time to fit (and tune) causal tree 0.21934795379638672 seconds ---
# --- Time to fit (and tune) causal tree 0.7546830177307129 seconds ---
# Additional visits: 8668.603130142294
# Additional visits: 8872.69969698798
# Additional visits: 8665.445628049614
# --- Time to fit (and tune) causal tree 7.0372679233551025 seconds ---
# --- Time to fit (and tune) causal tree 18.58105158805847 seconds ---
# Additional visits: 8577.526812824179
# --- Time to fit (and tune) causal tree 2.5370688438415527 seconds ---
# Additional visits: 8760.486946255036
# --- Time to fit (and tune) causal tree 0.035422325134277344 seconds ---
# --- Time to fit (and tune) causal tree 0.07545852661132812 seconds ---
# Additional visits: 8863.032472907138
# Additional visits: 8350.17375512261
# --- Time to fit (and tune) causal tree 0.22734403610229492 seconds ---
# Additional visits: 8523.14099043236
# --- Time to fit (and tune) causal tree 0.7333047389984131 seconds ---
# Additional visits: 8889.095148896433
# Additional visits: 8285.772507279855
# --- Time to fit (and tune) causal tree 7.172643184661865 seconds ---
# --- Time to fit (and tune) causal tree 2.415817975997925 seconds ---
# Additional visits: 8942.66279922764
# --- Time to fit (and tune) causal tree 0.03487801551818848 seconds ---
# Additional visits: 7908.161317264262
# Additional visits: 8565.893373513518
# Additional visits: 8807.333340095473
# --- Time to fit (and tune) causal tree 0.08053421974182129 seconds ---
# --- Time to fit (and tune) causal tree 0.22367382049560547 seconds ---
# --- Time to fit (and tune) causal tree 0.7230682373046875 seconds ---
# Additional visits: 7683.96228790447
# Additional visits: 8617.276212445217
# --- Time to fit (and tune) causal tree 23.55107569694519 seconds ---
# --- Time to fit (and tune) causal tree 2.118743896484375 seconds ---
# --- Time to fit (and tune) causal tree 7.17931342124939 seconds ---
# Additional visits: 8327.177642359908
# --- Time to fit (and tune) causal tree 19.5929856300354 seconds ---
# Additional visits: 8483.244753529707
# Additional visits: 8370.878822301853
# Additional visits: 8145.515101325725
# --- Time to fit (and tune) causal tree 0.032822608947753906 seconds ---
# --- Time to fit (and tune) causal tree 0.07610273361206055 seconds ---
# --- Time to fit (and tune) causal tree 0.23899102210998535 seconds ---
# Additional visits: 8512.499313166767
# --- Time to fit (and tune) causal tree 0.7058775424957275 seconds ---
# --- Time to fit (and tune) causal tree 6.173062086105347 seconds ---
# Additional visits: 8481.127125113637
# Additional visits: 6664.0850828320235
# Additional visits: 8670.721516698351
# --- Time to fit (and tune) causal tree 19.741809606552124 seconds ---
# Additional visits: 7974.670740475262
# --- Time to fit (and tune) causal tree 0.03369879722595215 seconds ---
# --- Time to fit (and tune) causal tree 2.0828697681427 seconds ---
# Additional visits: 8589.635855115273
# Additional visits: 8638.53559338548
# --- Time to fit (and tune) causal tree 0.0775456428527832 seconds ---
# --- Time to fit (and tune) causal tree 0.2317523956298828 seconds ---
# Additional visits: 8937.068207337135
# Additional visits: 8425.548762466364
# Additional visits: 5081.759751428216
# --- Time to fit (and tune) causal tree 0.6960911750793457 seconds ---
# Additional visits: 8653.719561205366
# --- Time to fit (and tune) causal tree 6.10725736618042 seconds ---
# Additional visits: 7545.411073170467
# --- Time to fit (and tune) causal tree 2.40402889251709 seconds ---
# --- Time to fit (and tune) causal tree 0.03632330894470215 seconds ---
# --- Time to fit (and tune) causal tree 20.355170011520386 seconds ---
# Additional visits: 6737.763783500065
# Additional visits: 8774.408430946627
# --- Time to fit (and tune) causal tree 0.07788681983947754 seconds ---
# --- Time to fit (and tune) causal tree 0.23535847663879395 seconds ---
# Additional visits: 8844.882838013582
# Additional visits: 8388.556010982998
# Additional visits: 7745.743563099463
# --- Time to fit (and tune) causal tree 16.519699335098267 seconds ---
# --- Time to fit (and tune) causal tree 0.7520108222961426 seconds ---
# Additional visits: 8293.288516445828
# --- Time to fit (and tune) causal tree 7.5272157192230225 seconds ---
# --- Time to fit (and tune) causal tree 2.544236660003662 seconds ---
# Additional visits: 7956.6020579318465
# Additional visits: 7402.085185364826
# Additional visits: 8784.779903870434
# --- Time to fit (and tune) causal tree 0.03406119346618652 seconds ---
# --- Time to fit (and tune) causal tree 0.08101391792297363 seconds ---
# --- Time to fit (and tune) causal tree 0.22785329818725586 seconds ---
# --- Time to fit (and tune) causal tree 15.811321496963501 seconds ---
# Additional visits: 7851.367435342687
# Additional visits: 8504.914384051648
# Additional visits: 8530.006593411064
# --- Time to fit (and tune) causal tree 7.142831563949585 seconds ---
# --- Time to fit (and tune) causal tree 0.716935396194458 seconds ---
# Additional visits: 8732.730770298233
# Additional visits: 8572.284241220279
# Additional visits: 8751.01414781011
# --- Time to fit (and tune) causal tree 2.169213056564331 seconds ---
# --- Time to fit (and tune) causal tree 0.03400015830993652 seconds ---
# --- Time to fit (and tune) causal tree 0.07945013046264648 seconds ---
# Additional visits: 7990.2746901701
# Additional visits: 8220.808416920112
# --- Time to fit (and tune) causal tree 0.21563386917114258 seconds ---
# --- Time to fit (and tune) causal tree 0.7160744667053223 seconds ---
# Additional visits: 7984.4061322661555
# Additional visits: 8581.323404687224
# Additional visits: 8632.557078591852
# Additional visits: 8856.205915538514
# --- Time to fit (and tune) causal tree 7.063706874847412 seconds ---
# --- Time to fit (and tune) causal tree 0.035552263259887695 seconds ---
# Additional visits: 8323.266928344485
# --- Time to fit (and tune) causal tree 2.351553440093994 seconds ---
# Additional visits: 8102.814624158824
# --- Time to fit (and tune) causal tree 0.08115291595458984 seconds ---
# Additional visits: 8693.264666997993
# --- Time to fit (and tune) causal tree 0.213944673538208 seconds ---
# --- Time to fit (and tune) causal tree 20.740123748779297 seconds ---
# --- Time to fit (and tune) causal tree 0.7078275680541992 seconds ---
# Additional visits: 8422.734867072271
# Additional visits: 796.2961061210707
# Additional visits: 7359.42239877302
# --- Time to fit (and tune) causal tree 2.3010120391845703 seconds ---
# --- Time to fit (and tune) causal tree 18.34963631629944 seconds ---
# --- Time to fit (and tune) causal tree 7.027449607849121 seconds ---
# Additional visits: 8451.50571118286
# --- Time to fit (and tune) causal tree 0.033601999282836914 seconds ---
# Additional visits: 8290.179391282789
# Additional visits: 8725.203524227034
# --- Time to fit (and tune) causal tree 0.08059501647949219 seconds ---
# Additional visits: 8245.297680487716
# --- Time to fit (and tune) causal tree 0.22901463508605957 seconds ---
# --- Time to fit (and tune) causal tree 0.7159245014190674 seconds ---
# Additional visits: 8876.535687367892
# --- Time to fit (and tune) causal tree 7.032033443450928 seconds ---
# Additional visits: 8573.552082977567
# --- Time to fit (and tune) causal tree 18.53398847579956 seconds ---
# Additional visits: 8612.447801298573
# Additional visits: 8438.68523318958
# --- Time to fit (and tune) causal tree 2.1060588359832764 seconds ---
# --- Time to fit (and tune) causal tree 0.034076690673828125 seconds ---
# Additional visits: 8782.785527233305
# Additional visits: 8714.58025650442
# --- Time to fit (and tune) causal tree 0.07900524139404297 seconds ---
# --- Time to fit (and tune) causal tree 0.2517833709716797 seconds ---
# Additional visits: 8610.108861488241
# Additional visits: 9041.889667973164
# --- Time to fit (and tune) causal tree 0.6964983940124512 seconds ---
# Additional visits: 6617.763178452905
# --- Time to fit (and tune) causal tree 18.603842973709106 seconds ---
# --- Time to fit (and tune) causal tree 2.2254576683044434 seconds ---
# Additional visits: 8436.91426016099
# Additional visits: 8444.161243379007
# --- Time to fit (and tune) causal tree 7.568127632141113 seconds ---
# --- Time to fit (and tune) causal tree 0.035285234451293945 seconds ---
# Additional visits: 8739.965530160725
# Additional visits: 7955.201691851231
# --- Time to fit (and tune) causal tree 0.07882523536682129 seconds ---
# --- Time to fit (and tune) causal tree 0.21984219551086426 seconds ---
# Additional visits: 8711.779643811133
# Additional visits: 8690.691425277113
# --- Time to fit (and tune) causal tree 0.734769344329834 seconds ---
# Additional visits: 6405.145548832443
# --- Time to fit (and tune) causal tree 7.458378314971924 seconds ---
# Additional visits: 7971.735466475062
# Additional visits: 8819.633924718284
# --- Time to fit (and tune) causal tree 2.4847264289855957 seconds ---
# --- Time to fit (and tune) causal tree 0.035608768463134766 seconds ---
# Additional visits: 7521.769051146675
# --- Time to fit (and tune) causal tree 20.265750408172607 seconds ---
# --- Time to fit (and tune) causal tree 0.07707333564758301 seconds ---
# Additional visits: 8702.087044727708
# Additional visits: 8642.520785512948
# Additional visits: 7976.132724078688
# --- Time to fit (and tune) causal tree 0.2139301300048828 seconds ---
# --- Time to fit (and tune) causal tree 0.6847858428955078 seconds ---
# Additional visits: 8601.811521365627
# --- Time to fit (and tune) causal tree 6.6509785652160645 seconds ---
# Additional visits: 8471.528970962767
# --- Time to fit (and tune) causal tree 2.0467708110809326 seconds ---
# Additional visits: 8633.29506307301
# Additional visits: 8580.22929556418
# --- Time to fit (and tune) causal tree 0.03419661521911621 seconds ---
# --- Time to fit (and tune) causal tree 0.07916569709777832 seconds ---
# --- Time to fit (and tune) causal tree 20.173288583755493 seconds ---
# Additional visits: 8643.867105161075
# --- Time to fit (and tune) causal tree 0.23416948318481445 seconds ---
# Additional visits: 8535.929225466503
# Additional visits: 8519.928551559897
# --- Time to fit (and tune) causal tree 5.906573295593262 seconds ---
# --- Time to fit (and tune) causal tree 0.6655962467193604 seconds ---
# Additional visits: 8239.241731473461
# --- Time to fit (and tune) causal tree 18.199394702911377 seconds ---
# Additional visits: 8309.664683949424
# Additional visits: 8688.114178945378
# --- Time to fit (and tune) causal tree 0.03429603576660156 seconds ---
# Additional visits: 8654.504464121612
# --- Time to fit (and tune) causal tree 0.07741618156433105 seconds ---
# --- Time to fit (and tune) causal tree 2.425548553466797 seconds ---
# Additional visits: 8941.293371417414
# --- Time to fit (and tune) causal tree 0.22355365753173828 seconds ---
# Additional visits: 7045.3098219933045
# Additional visits: 8590.80100469207
# Additional visits: 8235.451279324518
# --- Time to fit (and tune) causal tree 0.6393270492553711 seconds ---
# Additional visits: 8693.054990232109
# Additional visits: 8720.481644621097
# --- Time to fit (and tune) causal tree 6.892598867416382 seconds ---
# --- Time to fit (and tune) causal tree 0.03488492965698242 seconds ---
# --- Time to fit (and tune) causal tree 2.1646251678466797 seconds ---
# Additional visits: 8530.468874517817
# --- Time to fit (and tune) causal tree 20.1287522315979 seconds ---
# Additional visits: 8601.217613805338
# --- Time to fit (and tune) causal tree 0.07841968536376953 seconds ---
# Additional visits: 8582.978701545931
# --- Time to fit (and tune) causal tree 0.22638916969299316 seconds ---
# Additional visits: 7892.249374223597
# --- Time to fit (and tune) causal tree 0.6922729015350342 seconds ---
# --- Time to fit (and tune) causal tree 17.14124345779419 seconds ---
# Additional visits: 8986.361450248838
# --- Time to fit (and tune) causal tree 6.402951240539551 seconds ---
# Additional visits: 8156.9343518600235
# --- Time to fit (and tune) causal tree 2.294942617416382 seconds ---
# Additional visits: 8739.140122315777
# Additional visits: 8242.772940017048
# --- Time to fit (and tune) causal tree 0.03455185890197754 seconds ---
# Additional visits: 8695.413249120045
# --- Time to fit (and tune) causal tree 0.07906651496887207 seconds ---
# --- Time to fit (and tune) causal tree 0.20784974098205566 seconds ---
# Additional visits: 8314.081014892354
# --- Time to fit (and tune) causal tree 0.7315483093261719 seconds ---
# Additional visits: 8799.812001571123
# Additional visits: 8643.593030645568
# --- Time to fit (and tune) causal tree 7.037164926528931 seconds ---
# Additional visits: 8574.195339033067
# Additional visits: 8029.420826537679
# Additional visits: 8723.195432042328
# Additional visits: 8590.391002447022
# Additional visits: 8838.980741199664
# --- Time to fit (and tune) causal tree 0.033514976501464844 seconds ---
# --- Time to fit (and tune) causal tree 0.07660961151123047 seconds ---
# --- Time to fit (and tune) causal tree 0.22171854972839355 seconds ---
# --- Time to fit (and tune) causal tree 2.546794891357422 seconds ---
# --- Time to fit (and tune) causal tree 20.76398205757141 seconds ---
# --- Time to fit (and tune) causal tree 0.7753725051879883 seconds ---
# Additional visits: 7208.536094850674
# Additional visits: 8299.080420758564
# Additional visits: 8235.671343623382
# --- Time to fit (and tune) causal tree 6.897640228271484 seconds ---
# --- Time to fit (and tune) causal tree 19.491929531097412 seconds ---
# Additional visits: 8330.354656920108
# --- Time to fit (and tune) causal tree 2.2738490104675293 seconds ---
# --- Time to fit (and tune) causal tree 0.03509855270385742 seconds ---
# Additional visits: 8650.558836177297
# --- Time to fit (and tune) causal tree 0.08060407638549805 seconds ---
# Additional visits: 8241.914933114065
# Additional visits: 7647.253149220773
# --- Time to fit (and tune) causal tree 0.2453920841217041 seconds ---
# --- Time to fit (and tune) causal tree 0.6991267204284668 seconds ---
# Additional visits: 6174.679922791041
# Additional visits: 8773.355834794324
# Additional visits: 8140.6641491615865
# --- Time to fit (and tune) causal tree 7.479647397994995 seconds ---
# --- Time to fit (and tune) causal tree 2.113433361053467 seconds ---
# --- Time to fit (and tune) causal tree 19.047772645950317 seconds ---
# Additional visits: 8429.947787857665
# Additional visits: 8187.102426882287
# Additional visits: 8598.640126961202
# --- Time to fit (and tune) causal tree 0.033838748931884766 seconds ---
# --- Time to fit (and tune) causal tree 0.07693672180175781 seconds ---
# --- Time to fit (and tune) causal tree 0.24144196510314941 seconds ---
# Additional visits: 8750.924270617286
# Additional visits: 8245.999172570002
# --- Time to fit (and tune) causal tree 0.644176721572876 seconds ---
# Additional visits: 8622.57749241368
# --- Time to fit (and tune) causal tree 6.01562237739563 seconds ---
# Additional visits: 8187.600933993484
# --- Time to fit (and tune) causal tree 2.270725727081299 seconds ---
# --- Time to fit (and tune) causal tree 18.88761854171753 seconds ---
# Additional visits: 8552.980031825364
# Additional visits: 8290.970658653177
# --- Time to fit (and tune) causal tree 0.03383374214172363 seconds ---
# --- Time to fit (and tune) causal tree 0.07659912109375 seconds ---
# Additional visits: 8450.67923660077
# --- Time to fit (and tune) causal tree 0.2241668701171875 seconds ---
# Additional visits: 8533.696612090382
# Additional visits: 8612.060894419517
# Additional visits: 6309.799386231011
# --- Time to fit (and tune) causal tree 0.7865030765533447 seconds ---
# Additional visits: 8413.494328647834
# --- Time to fit (and tune) causal tree 2.5200018882751465 seconds ---
# --- Time to fit (and tune) causal tree 7.3340723514556885 seconds ---
# Additional visits: 8302.0894023818
# --- Time to fit (and tune) causal tree 19.95478343963623 seconds ---
# Additional visits: 8649.536165482106
# --- Time to fit (and tune) causal tree 0.037049293518066406 seconds ---
# Additional visits: 8997.675044441808
# --- Time to fit (and tune) causal tree 0.08139324188232422 seconds ---
# --- Time to fit (and tune) causal tree 0.2301633358001709 seconds ---
# Additional visits: 8594.033119118218
# Additional visits: 9048.937295574086
# --- Time to fit (and tune) causal tree 0.7333920001983643 seconds ---
# --- Time to fit (and tune) causal tree 17.097187042236328 seconds ---
# Additional visits: 8455.380780782156
# Additional visits: 8425.840848874857
# --- Time to fit (and tune) causal tree 7.189419746398926 seconds ---
# Additional visits: 8775.013234849703
# --- Time to fit (and tune) causal tree 2.3222479820251465 seconds ---
# --- Time to fit (and tune) causal tree 0.03342866897583008 seconds ---
# Additional visits: 8485.711132729184
# --- Time to fit (and tune) causal tree 0.0775759220123291 seconds ---
# Additional visits: 8504.085225659985
# --- Time to fit (and tune) causal tree 0.23761940002441406 seconds ---
# Additional visits: 8790.711436752046
# Additional visits: 8642.882618249927
# Additional visits: 8438.507592582399
# --- Time to fit (and tune) causal tree 0.6469545364379883 seconds ---
# --- Time to fit (and tune) causal tree 6.8464579582214355 seconds ---
# Additional visits: 8195.717160538614
# --- Time to fit (and tune) causal tree 2.093169927597046 seconds ---
# Additional visits: 8672.056280248764
# --- Time to fit (and tune) causal tree 0.03512883186340332 seconds ---
# Additional visits: 8703.067406596714
# Additional visits: 8640.229055640211
# Additional visits: 8582.20030577848
# --- Time to fit (and tune) causal tree 0.07478117942810059 seconds ---
# --- Time to fit (and tune) causal tree 0.2174842357635498 seconds ---
# --- Time to fit (and tune) causal tree 0.7312922477722168 seconds ---
# --- Time to fit (and tune) causal tree 22.827115774154663 seconds ---
# --- Time to fit (and tune) causal tree 16.90306854248047 seconds ---
# Additional visits: 8665.664847512147
# Additional visits: 8670.557021461542
# --- Time to fit (and tune) causal tree 7.203678369522095 seconds ---
# Additional visits: 8106.468190481735
# --- Time to fit (and tune) causal tree 2.1795804500579834 seconds ---
# Additional visits: 8389.588291465052
# Additional visits: 8633.174828036124
# --- Time to fit (and tune) causal tree 0.03550553321838379 seconds ---
# Additional visits: 8785.441662776178
# --- Time to fit (and tune) causal tree 0.07884621620178223 seconds ---
# --- Time to fit (and tune) causal tree 0.22976255416870117 seconds ---
# Additional visits: 8656.893222926426
# --- Time to fit (and tune) causal tree 0.6700518131256104 seconds ---
# Additional visits: 8149.851224102869
# --- Time to fit (and tune) causal tree 6.752482175827026 seconds ---
# Additional visits: 8751.17060308128
# --- Time to fit (and tune) causal tree 19.15535879135132 seconds ---
# Additional visits: 8665.736105132139
# --- Time to fit (and tune) causal tree 2.0985641479492188 seconds ---
# Additional visits: 8384.7114643077
# ...
# --- Time to fit (and tune) causal tree 6.6193015575408936 seconds ---
# Additional visits: 8516.696311145777
# --- Time to fit (and tune) causal tree 2.0578486919403076 seconds ---
# --- Time to fit (and tune) causal tree 19.410770893096924 seconds ---
# Additional visits: 8803.0230022986
# --- Time to fit (and tune) causal tree 0.03462839126586914 seconds ---
# Additional visits: 7884.489111137016
# --- Time to fit (and tune) causal tree 0.07456183433532715 seconds ---
# Additional visits: 8501.078900425708
# Additional visits: 8679.684718948853
# --- Time to fit (and tune) causal tree 0.2236769199371338 seconds ---
# Additional visits: 8125.5144551446965
# --- Time to fit (and tune) causal tree 0.7270669937133789 seconds ---
# Additional visits: 8645.871561787848
# --- Time to fit (and tune) causal tree 6.676684617996216 seconds ---
# Additional visits: 8707.829782606488
# Additional visits: 8884.476794310622
# Additional visits: 8214.153766497535
# --- Time to fit (and tune) causal tree 20.28047490119934 seconds ---
# --- Time to fit (and tune) causal tree 2.563577651977539 seconds ---
# --- Time to fit (and tune) causal tree 0.034938812255859375 seconds ---
# --- Time to fit (and tune) causal tree 0.0825035572052002 seconds ---
# Additional visits: 8547.295101786765
# --- Time to fit (and tune) causal tree 0.22146391868591309 seconds ---
# Additional visits: 8686.150969858323
# Additional visits: 8610.443478152813
# Additional visits: 8535.989817969963
# --- Time to fit (and tune) causal tree 0.6809630393981934 seconds ---
# Additional visits: 8014.319020298217
# --- Time to fit (and tune) causal tree 6.888168811798096 seconds ---
# --- Time to fit (and tune) causal tree 2.186110734939575 seconds ---
# Additional visits: 8046.799117975149
# --- Time to fit (and tune) causal tree 20.243727207183838 seconds ---
# --- Time to fit (and tune) causal tree 0.03488945960998535 seconds ---
# Additional visits: 8378.169972370324
# Additional visits: 8497.359763111739
# --- Time to fit (and tune) causal tree 0.07926273345947266 seconds ---
# --- Time to fit (and tune) causal tree 0.23091387748718262 seconds ---
# Additional visits: 8624.785952100945
# Additional visits: 8398.106920315628
# Additional visits: 8522.924967385912
# --- Time to fit (and tune) causal tree 0.7245662212371826 seconds ---
# --- Time to fit (and tune) causal tree 7.200450897216797 seconds ---
# --- Time to fit (and tune) causal tree 18.769294500350952 seconds ---
# Additional visits: 8908.720693221601
# Additional visits: 8545.13394524562
# --- Time to fit (and tune) causal tree 2.365880250930786 seconds ---
# Additional visits: 8602.145369072294
# --- Time to fit (and tune) causal tree 0.03555703163146973 seconds ---
# --- Time to fit (and tune) causal tree 0.07688117027282715 seconds ---
# Additional visits: 8322.856220537009
# --- Time to fit (and tune) causal tree 0.22195839881896973 seconds ---
# Additional visits: 8640.123985337239
# Additional visits: 8618.606119629058
# Additional visits: 8266.46986113868
# Additional visits: 9059.197906958158
# --- Time to fit (and tune) causal tree 0.6982982158660889 seconds ---
# --- Time to fit (and tune) causal tree 7.19957971572876 seconds ---
# Additional visits: 8244.692651377805
# --- Time to fit (and tune) causal tree 2.358733654022217 seconds ---
# Additional visits: 8528.493138256044
# --- Time to fit (and tune) causal tree 19.97011423110962 seconds ---
# Additional visits: 8163.563305646052
# --- Time to fit (and tune) causal tree 0.03479146957397461 seconds ---
# --- Time to fit (and tune) causal tree 0.07660508155822754 seconds ---
# --- Time to fit (and tune) causal tree 0.2240734100341797 seconds ---
# Additional visits: 8430.593134248773
# --- Time to fit (and tune) causal tree 0.6245427131652832 seconds ---
# Additional visits: 6883.260347804327
# Additional visits: 8827.295442608505
# --- Time to fit (and tune) causal tree 7.226916551589966 seconds ---
# Additional visits: 8453.638124141185
# Additional visits: 8533.983834142908
# --- Time to fit (and tune) causal tree 20.48989224433899 seconds ---
# --- Time to fit (and tune) causal tree 0.034575700759887695 seconds ---
# --- Time to fit (and tune) causal tree 2.2444655895233154 seconds ---
# Additional visits: 8223.329028608643
# Additional visits: 8563.173302171692
# --- Time to fit (and tune) causal tree 0.07771515846252441 seconds ---
# --- Time to fit (and tune) causal tree 0.25163722038269043 seconds ---
# Additional visits: 8603.2889415073
# Additional visits: 266.6331207913194
# Additional visits: 8765.573218829728
# --- Time to fit (and tune) causal tree 0.7087395191192627 seconds ---
# --- Time to fit (and tune) causal tree 6.746025323867798 seconds ---
# --- Time to fit (and tune) causal tree 18.516231298446655 seconds ---
# Additional visits: 8188.406974831173
# --- Time to fit (and tune) causal tree 2.084507703781128 seconds ---
# Additional visits: 8620.70549160814
# --- Time to fit (and tune) causal tree 0.03366208076477051 seconds ---
# Additional visits: 8573.74813734916
# Additional visits: 8579.159747379044
# --- Time to fit (and tune) causal tree 0.07920694351196289 seconds ---
# --- Time to fit (and tune) causal tree 0.22863554954528809 seconds ---
# Additional visits: 8548.160807954002
# Additional visits: 8513.230269141648
# Additional visits: 8657.105897838768
# --- Time to fit (and tune) causal tree 0.7419881820678711 seconds ---
# --- Time to fit (and tune) causal tree 6.89002537727356 seconds ---
# --- Time to fit (and tune) causal tree 19.272987127304077 seconds ---
# Additional visits: 8349.516128315701
# --- Time to fit (and tune) causal tree 2.34120512008667 seconds ---
# Additional visits: 8734.770983636427
# Additional visits: 8604.603625806987
# Additional visits: 8119.211502714298
# --- Time to fit (and tune) causal tree 0.03564572334289551 seconds ---
# --- Time to fit (and tune) causal tree 0.07976341247558594 seconds ---
# --- Time to fit (and tune) causal tree 0.23107576370239258 seconds ---
# Additional visits: 8717.747994560534
# --- Time to fit (and tune) causal tree 0.7006576061248779 seconds ---
# Additional visits: 8228.01058206562
# Additional visits: 8643.026161372398
# --- Time to fit (and tune) causal tree 6.65703272819519 seconds ---
# Additional visits: 8440.873033448483
# --- Time to fit (and tune) causal tree 18.502947330474854 seconds ---
# Additional visits: 8825.816524830127
# Additional visits: 8626.840199475886
# Additional visits: 8335.761673935342
# --- Time to fit (and tune) causal tree 0.03385210037231445 seconds ---
# --- Time to fit (and tune) causal tree 2.4486377239227295 seconds ---
# --- Time to fit (and tune) causal tree 0.08394455909729004 seconds ---
# --- Time to fit (and tune) causal tree 0.2218618392944336 seconds ---
# Additional visits: 8714.895040504429
# Additional visits: 8284.392233611774
# --- Time to fit (and tune) causal tree 0.6562919616699219 seconds ---
# Additional visits: 8716.093844888477
# --- Time to fit (and tune) causal tree 6.515188694000244 seconds ---
# Additional visits: 8251.261290353776
# --- Time to fit (and tune) causal tree 2.380824327468872 seconds ---
# Additional visits: 8409.359582717863
# Additional visits: 8562.563200969731
# --- Time to fit (and tune) causal tree 0.03288006782531738 seconds ---
# --- Time to fit (and tune) causal tree 19.725173234939575 seconds ---
# --- Time to fit (and tune) causal tree 0.0805366039276123 seconds ---
# Additional visits: 8302.960186464641
# Additional visits: 8794.289851192709
# --- Time to fit (and tune) causal tree 0.21201610565185547 seconds ---
# Additional visits: 8649.544160230378
# --- Time to fit (and tune) causal tree 0.6918919086456299 seconds ---
# Additional visits: 5832.333386642193
# --- Time to fit (and tune) causal tree 6.542141675949097 seconds ---
# Additional visits: 7799.821500379083
# --- Time to fit (and tune) causal tree 2.363032102584839 seconds ---
# --- Time to fit (and tune) causal tree 19.055320739746094 seconds ---
# Additional visits: 8455.236131588184
# Additional visits: 8639.16066545344
# --- Time to fit (and tune) causal tree 0.03289508819580078 seconds ---
# --- Time to fit (and tune) causal tree 0.08083868026733398 seconds ---
# Additional visits: 8607.15571818683
# --- Time to fit (and tune) causal tree 0.2214205265045166 seconds ---
# Additional visits: 7676.183800107935
# Additional visits: 8885.633358646866
# --- Time to fit (and tune) causal tree 0.6980574131011963 seconds ---
# Additional visits: 8411.237059222272
# Additional visits: 8532.8366663423
# --- Time to fit (and tune) causal tree 7.54603385925293 seconds ---
# --- Time to fit (and tune) causal tree 19.087977170944214 seconds ---
# Additional visits: 8485.954708940222
# Additional visits: 8720.265178816318
# --- Time to fit (and tune) causal tree 2.3544094562530518 seconds ---
# --- Time to fit (and tune) causal tree 0.03539013862609863 seconds ---
# Additional visits: 8438.956727539144
# --- Time to fit (and tune) causal tree 0.08325910568237305 seconds ---
# --- Time to fit (and tune) causal tree 0.21769261360168457 seconds ---
# Additional visits: 8522.78685618452
# Additional visits: 8530.138632491111
# Additional visits: 8452.334407581891
# --- Time to fit (and tune) causal tree 0.6426417827606201 seconds ---
# Additional visits: 7534.591852096129
# --- Time to fit (and tune) causal tree 7.362828493118286 seconds ---
# --- Time to fit (and tune) causal tree 2.1606037616729736 seconds ---
# Additional visits: 8130.1444879919045
# --- Time to fit (and tune) causal tree 0.03493356704711914 seconds ---
# --- Time to fit (and tune) causal tree 20.147923707962036 seconds ---
# Additional visits: 8519.488040326027
# Additional visits: 8295.44748717094
# --- Time to fit (and tune) causal tree 0.07808446884155273 seconds ---
# --- Time to fit (and tune) causal tree 0.22769498825073242 seconds ---
# Additional visits: 8826.389846295137
# Additional visits: 7907.788907774011
# --- Time to fit (and tune) causal tree 0.7269086837768555 seconds ---
# Additional visits: 8676.043754969201
# --- Time to fit (and tune) causal tree 7.088250160217285 seconds ---
# Additional visits: 8372.751097225251
# --- Time to fit (and tune) causal tree 19.48383617401123 seconds ---
# --- Time to fit (and tune) causal tree 2.2535154819488525 seconds ---
# Additional visits: 8147.47528202563
# Additional visits: 8502.00662693618
# --- Time to fit (and tune) causal tree 0.032796621322631836 seconds ---
# --- Time to fit (and tune) causal tree 0.07733726501464844 seconds ---
# Additional visits: 8563.882083669338
# --- Time to fit (and tune) causal tree 0.25225377082824707 seconds ---
# Additional visits: 8583.644990238688
# --- Time to fit (and tune) causal tree 16.826086044311523 seconds ---
# Additional visits: 3014.6146036676337
# Additional visits: 8892.002747950199
# --- Time to fit (and tune) causal tree 0.7279620170593262 seconds ---
# --- Time to fit (and tune) causal tree 6.872463941574097 seconds ---
# Additional visits: 8171.6087848646375
# Additional visits: 8077.889250041588
# Additional visits: 8565.363393522075
# --- Time to fit (and tune) causal tree 2.5545411109924316 seconds ---
# --- Time to fit (and tune) causal tree 0.03308510780334473 seconds ---
# Additional visits: 7281.595863680195
# --- Time to fit (and tune) causal tree 0.07605218887329102 seconds ---
# --- Time to fit (and tune) causal tree 0.22628045082092285 seconds ---
# Additional visits: 8557.919142483299
# --- Time to fit (and tune) causal tree 0.7364115715026855 seconds ---
# Additional visits: 4386.396764647378
# Additional visits: 7757.019789745687
# Additional visits: 9008.719013851256
# --- Time to fit (and tune) causal tree 7.524660110473633 seconds ---
# Additional visits: 8733.518797266408
# Additional visits: 8492.804430702727
# Additional visits: 8729.436321345227
# --- Time to fit (and tune) causal tree 0.03427886962890625 seconds ---
# --- Time to fit (and tune) causal tree 2.237623929977417 seconds ---
# --- Time to fit (and tune) causal tree 0.07673025131225586 seconds ---
# --- Time to fit (and tune) causal tree 20.916521787643433 seconds ---
# --- Time to fit (and tune) causal tree 0.2330625057220459 seconds ---
# Additional visits: 8318.949596072398
# --- Time to fit (and tune) causal tree 0.7030539512634277 seconds ---
# Additional visits: 7806.53093028507
# Additional visits: 5090.988964086943
# Additional visits: 7971.050052556586
# --- Time to fit (and tune) causal tree 6.942760705947876 seconds ---
# --- Time to fit (and tune) causal tree 18.156998872756958 seconds ---
# Additional visits: 7711.535779993584
# --- Time to fit (and tune) causal tree 0.033104658126831055 seconds ---
# --- Time to fit (and tune) causal tree 2.392611503601074 seconds ---
# Additional visits: 8257.914276130232
# --- Time to fit (and tune) causal tree 0.07718229293823242 seconds ---
# Additional visits: 8370.675451693012
# Additional visits: 8767.790555639627
# --- Time to fit (and tune) causal tree 0.24816250801086426 seconds ---
# Additional visits: 8260.370709906045
# --- Time to fit (and tune) causal tree 0.7477731704711914 seconds ---
# Additional visits: 8574.817950361536
# --- Time to fit (and tune) causal tree 6.771738290786743 seconds ---
# Additional visits: 8664.139883586437
# --- Time to fit (and tune) causal tree 2.3425891399383545 seconds ---
# Additional visits: 8705.14425564114
# Additional visits: 8172.421579102239
# --- Time to fit (and tune) causal tree 0.035108089447021484 seconds ---
# --- Time to fit (and tune) causal tree 20.957255125045776 seconds ---
# Additional visits: 8458.12580966686
# --- Time to fit (and tune) causal tree 0.07962560653686523 seconds ---
# Additional visits: 8923.910579063251
# --- Time to fit (and tune) causal tree 0.23028135299682617 seconds ---
# Additional visits: 8251.47932387834
# --- Time to fit (and tune) causal tree 0.8163917064666748 seconds ---
# Additional visits: 3550.9126973430157
# --- Time to fit (and tune) causal tree 7.03489875793457 seconds ---
# Additional visits: 8461.81944308712
# --- Time to fit (and tune) causal tree 2.3364357948303223 seconds ---
# Additional visits: 8506.503707493572
# --- Time to fit (and tune) causal tree 19.670222282409668 seconds ---
# --- Time to fit (and tune) causal tree 0.034757375717163086 seconds ---
# Additional visits: 8523.635764992936
# Additional visits: 8284.353908524667
# --- Time to fit (and tune) causal tree 0.07802414894104004 seconds ---
# --- Time to fit (and tune) causal tree 0.2151780128479004 seconds ---
# Additional visits: 8252.4626185093
# Additional visits: 8631.061906914549
# --- Time to fit (and tune) causal tree 0.6937272548675537 seconds ---
# Additional visits: 8697.030418438519
# Additional visits: 8665.969412299457
# --- Time to fit (and tune) causal tree 7.0571229457855225 seconds ---
# --- Time to fit (and tune) causal tree 2.1819608211517334 seconds ---
# Additional visits: 8694.7459513082
# Additional visits: 8362.171833772494
# --- Time to fit (and tune) causal tree 20.464477062225342 seconds ---
# Additional visits: 8929.194431550874
# --- Time to fit (and tune) causal tree 0.03517341613769531 seconds ---
# --- Time to fit (and tune) causal tree 0.07951831817626953 seconds ---
# --- Time to fit (and tune) causal tree 0.2411363124847412 seconds ---
# Additional visits: 8543.204071808792
# Additional visits: 8691.387845487803
# Additional visits: 7437.411811991763
# --- Time to fit (and tune) causal tree 0.7244610786437988 seconds ---
# Additional visits: 8516.520071402743
# --- Time to fit (and tune) causal tree 6.926698446273804 seconds ---
# --- Time to fit (and tune) causal tree 18.74165105819702 seconds ---
# Additional visits: 8052.106512402073
# --- Time to fit (and tune) causal tree 2.1425039768218994 seconds ---
# Additional visits: 8608.488207929437
# Additional visits: 8594.361382544248
# Additional visits: 8825.177129610915
# Additional visits: 8250.342563347978
# --- Time to fit (and tune) causal tree 6.516514778137207 seconds ---
# --- Time to fit (and tune) causal tree 18.32972550392151 seconds ---
# Additional visits: 8620.88391341339
# Additional visits: 8610.087229864048
# Additional visits: 8643.402062111101
# --- Time to fit (and tune) causal tree 18.603975534439087 seconds ---
# Additional visits: 8582.523367702464
# Additional visits: 8465.49541119705
# --- Time to fit (and tune) causal tree 16.128911018371582 seconds ---
# Additional visits: 8573.046416720861
# Additional visits: 8698.588544862865
# Done!
# Total time: 11.034 minutes

# %%
curve_results = pd.read_csv('../results/learning_curve_results.csv')
mask = curve_results.seed<50
backup = curve_results[mask].groupby('size').agg(
    performance=('improvement', 'mean'),
    std_dev=('improvement', 'std')
)
backup = pd.DataFrame(backup).reset_index()
backup['size'] = backup['size'].apply(lambda x: size2label[x])

margin = st.norm.ppf(0.975)
backup['upper_bound'] = backup.apply(lambda x: x['performance'] + margin*x['std_dev'], axis=1)
backup['lower_bound'] = backup.apply(lambda x: x['performance'] - margin*x['std_dev'], axis=1)
backup.to_csv('../results/learning_curve.csv', index=False)

# %%
eval_df['pred'] = 1
avg_benefit = get_improvement(eval_df,0.3)

breakevens = []
for size in curve_sizes[4:]:
    invested_size = size - curve_sizes[1]
    inference_size = eval_df.shape[0] - invested_size
    breakeven = 100 * (obs_benefit - avg_benefit) * invested_size / (inference_size * obs_benefit)
    breakevens.append(breakeven)
    print(breakeven)

pd.DataFrame(data={'size': curve_sizes[4:], 'breakeven': breakevens}).to_csv(
    '../results/breakeven.csv', index=False
)
# Out:
# Additional visits: 3167.6746795729027
# 0.8075514249770804
# 1.7505877334787912
# 3.7223676012214093

# %%
backup = pd.read_csv('../results/learning_curve.csv')
improvements = backup['performance']
labels = backup['size']
upper_bounds = backup['upper_bound']
lower_bounds = backup['lower_bound']
plt.plot(labels, [0, 0, 0, 0] + breakevens, color='black', linestyle='dashed', label="Break-even improvement")
plt.plot(labels, improvements[:4].tolist() + [None, None, None], color='tab:orange', label="Learning curve, observed")
plt.plot(labels, [None] + improvements[1:].tolist(), color='tab:orange', linestyle='dotted', label="Learning curve, unobserved")
# plt.fill_between(labels, upper_bounds, lower_bounds, color='gray', alpha=0.5)
plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])
plt.ylabel("Improvement of EM over OM")
plt.xlabel("Size of the experimental data")
plt.legend(loc='lower right')
# plt.savefig("../results/learning_curve.png", dpi=200, bbox_inches="tight")
# Out:
# /tmp/ipykernel_99715/2089823508.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:.0f}%'.format(x) for x in plt.gca().get_yticks()])

# %% [markdown]
# # Confidence Intervals

# %%
visits = obs_df.groupby('treatment').visit.mean()
counts = obs_df.groupby('treatment').visit.count()
variances = obs_df.groupby('treatment').visit.var()
print(f"Naive confounded: {(visits[1] - visits[0])*100:.2f}%")
print(f"S.E.: {np.sqrt((variances/counts).sum())*100*1.96:.2f}%")
###################
visits = df.groupby('treatment').visit.mean()
counts = df.groupby('treatment').visit.count()
variances = df.groupby('treatment').visit.var()
print(f"Ground truth: {(visits[1] - visits[0])*100:.2f}%")
print(f"S.E.: {np.sqrt((variances/counts).sum())*100*1.96:.2f}%")
# Out:
# Naive confounded: 4.08%
# S.E.: 0.03%
# Ground truth: 1.03%
# S.E.: 0.03%

# %% [markdown]
# Bootstrapping the experimental model.

# %%
from sklearn.utils import resample

bootstrap_size = 100
results = []
for i in range(bootstrap_size):
    print(i)
    data = resample(limited_exp, replace=True, random_state=i)
    tree = fit_tree(data, tune=False, min_samples_leaf=limited_tree.min_samples_leaf)
    result = tree.predict(data[limited_features]).mean()
    results.append(result)
# Out:
# 0
# --- Time to fit (and tune) causal tree 0.54060959815979 seconds ---
# 1
# --- Time to fit (and tune) causal tree 0.5220036506652832 seconds ---
# 2
# --- Time to fit (and tune) causal tree 0.5136191844940186 seconds ---
# 3
# --- Time to fit (and tune) causal tree 0.5373034477233887 seconds ---
# 4
# --- Time to fit (and tune) causal tree 0.4933624267578125 seconds ---
# 5
# --- Time to fit (and tune) causal tree 0.5362660884857178 seconds ---
# 6
# --- Time to fit (and tune) causal tree 0.4797847270965576 seconds ---
# 7
# --- Time to fit (and tune) causal tree 0.5348711013793945 seconds ---
# 8
# --- Time to fit (and tune) causal tree 0.5634500980377197 seconds ---
# 9
# --- Time to fit (and tune) causal tree 0.6456456184387207 seconds ---
# 10
# --- Time to fit (and tune) causal tree 0.5517866611480713 seconds ---
# 11
# --- Time to fit (and tune) causal tree 0.5633797645568848 seconds ---
# 12
# --- Time to fit (and tune) causal tree 0.5730924606323242 seconds ---
# 13
# --- Time to fit (and tune) causal tree 0.5725953578948975 seconds ---
# 14
# --- Time to fit (and tune) causal tree 0.5448894500732422 seconds ---
# 15
# --- Time to fit (and tune) causal tree 0.5260708332061768 seconds ---
# 16
# --- Time to fit (and tune) causal tree 0.5704500675201416 seconds ---
# 17
# --- Time to fit (and tune) causal tree 0.56109619140625 seconds ---
# 18
# --- Time to fit (and tune) causal tree 0.5695464611053467 seconds ---
# 19
# --- Time to fit (and tune) causal tree 0.5839443206787109 seconds ---
# 20
# --- Time to fit (and tune) causal tree 0.5107896327972412 seconds ---
# 21
# --- Time to fit (and tune) causal tree 0.53023362159729 seconds ---
# 22
# --- Time to fit (and tune) causal tree 0.5461065769195557 seconds ---
# 23
# --- Time to fit (and tune) causal tree 0.5520026683807373 seconds ---
# 24
# --- Time to fit (and tune) causal tree 0.5793194770812988 seconds ---
# 25
# --- Time to fit (and tune) causal tree 0.5647275447845459 seconds ---
# 26
# --- Time to fit (and tune) causal tree 0.5175950527191162 seconds ---
# 27
# --- Time to fit (and tune) causal tree 0.550518274307251 seconds ---
# 28
# --- Time to fit (and tune) causal tree 0.5198016166687012 seconds ---
# 29
# --- Time to fit (and tune) causal tree 0.514962911605835 seconds ---
# 30
# --- Time to fit (and tune) causal tree 0.5364565849304199 seconds ---
# 31
# --- Time to fit (and tune) causal tree 0.5101237297058105 seconds ---
# 32
# --- Time to fit (and tune) causal tree 0.5358319282531738 seconds ---
# 33
# --- Time to fit (and tune) causal tree 0.5028729438781738 seconds ---
# 34
# --- Time to fit (and tune) causal tree 0.5397865772247314 seconds ---
# 35
# --- Time to fit (and tune) causal tree 0.5636727809906006 seconds ---
# 36
# --- Time to fit (and tune) causal tree 0.5289006233215332 seconds ---
# 37
# --- Time to fit (and tune) causal tree 0.4763667583465576 seconds ---
# 38
# --- Time to fit (and tune) causal tree 0.51802659034729 seconds ---
# 39
# --- Time to fit (and tune) causal tree 0.54203200340271 seconds ---
# 40
# --- Time to fit (and tune) causal tree 0.5553483963012695 seconds ---
# 41
# --- Time to fit (and tune) causal tree 0.552605152130127 seconds ---
# 42
# --- Time to fit (and tune) causal tree 0.5331368446350098 seconds ---
# 43
# --- Time to fit (and tune) causal tree 0.5055603981018066 seconds ---
# 44
# --- Time to fit (and tune) causal tree 0.575232982635498 seconds ---
# 45
# --- Time to fit (and tune) causal tree 0.5210537910461426 seconds ---
# 46
# --- Time to fit (and tune) causal tree 0.49537134170532227 seconds ---
# 47
# --- Time to fit (and tune) causal tree 0.5080835819244385 seconds ---
# 48
# --- Time to fit (and tune) causal tree 0.4928748607635498 seconds ---
# 49
# --- Time to fit (and tune) causal tree 0.5742006301879883 seconds ---
# 50
# --- Time to fit (and tune) causal tree 0.5381550788879395 seconds ---
# 51
# --- Time to fit (and tune) causal tree 0.5761127471923828 seconds ---
# 52
# --- Time to fit (and tune) causal tree 0.5319650173187256 seconds ---
# 53
# --- Time to fit (and tune) causal tree 0.5466518402099609 seconds ---
# 54
# --- Time to fit (and tune) causal tree 0.48631954193115234 seconds ---
# 55
# --- Time to fit (and tune) causal tree 0.5114431381225586 seconds ---
# 56
# --- Time to fit (and tune) causal tree 0.5246810913085938 seconds ---
# 57
# --- Time to fit (and tune) causal tree 0.5215656757354736 seconds ---
# 58
# --- Time to fit (and tune) causal tree 0.5084686279296875 seconds ---
# 59
# --- Time to fit (and tune) causal tree 0.5699863433837891 seconds ---
# 60
# --- Time to fit (and tune) causal tree 0.5367536544799805 seconds ---
# 61
# --- Time to fit (and tune) causal tree 0.5147018432617188 seconds ---
# 62
# --- Time to fit (and tune) causal tree 0.5439779758453369 seconds ---
# 63
# --- Time to fit (and tune) causal tree 0.4864785671234131 seconds ---
# 64
# --- Time to fit (and tune) causal tree 0.5280086994171143 seconds ---
# 65
# --- Time to fit (and tune) causal tree 0.5177597999572754 seconds ---
# 66
# --- Time to fit (and tune) causal tree 0.5766117572784424 seconds ---
# 67
# --- Time to fit (and tune) causal tree 0.4987308979034424 seconds ---
# 68
# --- Time to fit (and tune) causal tree 0.5505228042602539 seconds ---
# 69
# --- Time to fit (and tune) causal tree 0.5246601104736328 seconds ---
# 70
# --- Time to fit (and tune) causal tree 0.57588791847229 seconds ---
# 71
# --- Time to fit (and tune) causal tree 0.5257821083068848 seconds ---
# 72
# --- Time to fit (and tune) causal tree 0.5598008632659912 seconds ---
# 73
# --- Time to fit (and tune) causal tree 0.5321013927459717 seconds ---
# 74
# --- Time to fit (and tune) causal tree 0.5177807807922363 seconds ---
# 75
# --- Time to fit (and tune) causal tree 0.5368287563323975 seconds ---
# 76
# --- Time to fit (and tune) causal tree 0.5117111206054688 seconds ---
# 77
# --- Time to fit (and tune) causal tree 0.5498309135437012 seconds ---
# 78
# --- Time to fit (and tune) causal tree 0.5831699371337891 seconds ---
# 79
# --- Time to fit (and tune) causal tree 0.5064387321472168 seconds ---
# 80
# --- Time to fit (and tune) causal tree 0.5413253307342529 seconds ---
# 81
# --- Time to fit (and tune) causal tree 0.5011541843414307 seconds ---
# 82
# --- Time to fit (and tune) causal tree 0.4973635673522949 seconds ---
# 83
# --- Time to fit (and tune) causal tree 0.5210287570953369 seconds ---
# 84
# --- Time to fit (and tune) causal tree 0.5145721435546875 seconds ---
# 85
# --- Time to fit (and tune) causal tree 0.5130875110626221 seconds ---
# 86
# --- Time to fit (and tune) causal tree 0.5425910949707031 seconds ---
# 87
# --- Time to fit (and tune) causal tree 0.4852001667022705 seconds ---
# 88
# --- Time to fit (and tune) causal tree 0.5183405876159668 seconds ---
# 89
# --- Time to fit (and tune) causal tree 0.5004024505615234 seconds ---
# 90
# --- Time to fit (and tune) causal tree 0.570366621017456 seconds ---
# 91
# --- Time to fit (and tune) causal tree 0.49765658378601074 seconds ---
# 92
# --- Time to fit (and tune) causal tree 0.5313210487365723 seconds ---
# 93
# --- Time to fit (and tune) causal tree 0.5015795230865479 seconds ---
# 94
# --- Time to fit (and tune) causal tree 0.5261986255645752 seconds ---
# 95
# --- Time to fit (and tune) causal tree 0.656998872756958 seconds ---
# 96
# --- Time to fit (and tune) causal tree 0.5049057006835938 seconds ---
# 97
# --- Time to fit (and tune) causal tree 0.5580770969390869 seconds ---
# 98
# --- Time to fit (and tune) causal tree 0.5560235977172852 seconds ---
# 99
# --- Time to fit (and tune) causal tree 0.6010100841522217 seconds ---

# %%
pd.Series(results).hist()
print(f"Unconfounded model: {np.mean(results)*100:.2f}%")
print(f"Unconfounded model (SE): {np.std(results)*100*1.96:.2f}%")
# Out:
# Unconfounded model: 1.37%
# Unconfounded model (SE): 0.43%

# %%
bootstrap_size = 10
results = []
for i in range(bootstrap_size):
    print(i)
    data = resample(obs_df, replace=True, random_state=i)
    #tree = fit_tree(data, tune=False, min_samples_leaf=obs_tree.min_samples_leaf)
    tree = fit_tree(data, tune=False, min_samples_leaf=32000)
    result = tree.predict(data[limited_features]).mean()
    results.append(result)
# Out:
# 0
# --- Time to fit (and tune) causal tree 208.7095718383789 seconds ---
# 1
# --- Time to fit (and tune) causal tree 357.01459646224976 seconds ---
# 2
# --- Time to fit (and tune) causal tree 353.66125321388245 seconds ---
# 3
# --- Time to fit (and tune) causal tree 186.21985268592834 seconds ---
# 4
# --- Time to fit (and tune) causal tree 196.14847135543823 seconds ---
# 5
# --- Time to fit (and tune) causal tree 202.83232879638672 seconds ---
# 6
# --- Time to fit (and tune) causal tree 190.43830251693726 seconds ---
# 7
# --- Time to fit (and tune) causal tree 188.8630712032318 seconds ---
# 8
# --- Time to fit (and tune) causal tree 197.38664031028748 seconds ---
# 9
# --- Time to fit (and tune) causal tree 193.81672048568726 seconds ---

# %%
pd.Series(results).hist()
# Out:
# <AxesSubplot:>

# %%
print(f"Confounded model: {pd.Series(results).mean()*100:.2f}%")
print(f"Confounded model S.E.: {pd.Series(results).std()*100*1.96:.2f}%")
# Out:
# Confounded model: 2.85%
# Confounded model S.E.: 0.07%
